# %%
'''
Reference:
Example script from Keras Github Repository keras/examples/lstm_text_generation.py
https://github.com/keras-team/keras

This network is trained with all the song lyrics from Donna Summer
only, which contains a total of 236908 characters. The length of each block of sequence is 40
characters with step size of 3. The LSTM hidden layer has 128 units, followed by the dense
layer with size of the character set and softmax activation. The model is optimized through
RMSprop on categorical cross entropy. The batch size is 128, with 60 training iterations. The
diversity values are 0.2, 0.5, 1.0, and 1.2.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = io.open(path, encoding='utf-8').read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 524288/600901 [=========================>....] - ETA: 0scorpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200285/200285 [==============================] - 131s - loss: 1.9946
#
# ----- diversity: 0.2
# ----- Generating with seed: " firmly and forever chained to its place"
#  firmly and forever chained to its place and the sense and the supposition and has no a conscions and the sension and which all and and and and and and to the self-canse and and it the for the sense and the sens of the sension of the sense and and and and and and and and and and the sense and in the sense and and the supposition and and the sense of the supposition of the sensible and the sension and and and and and the sension of the s
#
# ----- diversity: 0.5
# ----- Generating with seed: " firmly and forever chained to its place"
#  firmly and forever chained to its place a sufferent the proble in consequatic the something in the consequally of the will was formaning the modication of all love and morality to in the centiathess and that impordiced and in the men of the compory of the not and as a remanial will, and the things that is it ste condicions and and amples this and the indistant and in the sens of the possible without for the sense of the suffer to it we
#
# ----- diversity: 1.0
# ----- Generating with seed: " firmly and forever chained to its place"
#  firmly and forever chained to its places, ay which a ide as paik no not discive--evirrouk in ok should of longing falsen it is no hof chiloce and
# fosming it distent all for therevariboible madaliti,nablever, orle, the a herstandines in scili in problifity hruding a whulh wa fo edied and that
# thes. the consible be for whend of the moirftiw such almose sitpoble worle hage not hisharness and incritionive dossions of we consciouatity forma
#
# ----- diversity: 1.2
# ----- Generating with seed: " firmly and forever chained to its place"
#  firmly and forever chained to its places one and let.
# need koodmpy, therless, thaithion miseahme. and be . nat laculy
# proreoble "whre for to ceness to ideailing manyaring,
# a
# nonot and be not
# and
# concemiaiss will ina with alusselves. in owguled willy hanksfay cupwake nevelenconuncientsy, coditions, are  of will camsce wastar?
# no lhyigiess and and facds a in, a "nature
# for waicefle sichofrmen as atteiv
# aont of aldeh nature peccopsoniful,
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200285/200285 [==============================] - 124s - loss: 1.6405
#
# ----- diversity: 0.2
# ----- Generating with seed: "s end;
#      a wizard wrought it, he the "
# s end;
#      a wizard wrought it, he the most the greatest and the power the most and and the soul of the some of the longer the world and consertion, and the strange of the most the property of the super to be the most and and the most and the procises of the power the proper to the most and the procises of the power the property the properstions and the constite of the power the south the soul to the problem to the most the infortual a
#
# ----- diversity: 0.5
# ----- Generating with seed: "s end;
#      a wizard wrought it, he the "
# s end;
#      a wizard wrought it, he the suppose and everythereate for the some the most from the sowe to the properstons and therefore he stand supposent, the some power that wishes and themselves now do refited a destruded to the superness of the werdes and more and of his the fact of beare the philosophical one who macher as the "good the soul suppearable to german to the against hover of the sense and stand must not the and contrain
#
# ----- diversity: 1.0
# ----- Generating with seed: "s end;
#      a wizard wrought it, he the "
# s end;
#      a wizard wrought it, he the indegrity evol be thingtine be the
# mean. alcoself, hard--they in wishes
# at one addop in the poorth
# deventual
# power in the prict adatted however freecome things is are as human and wemoric madimantal complectians the word a free dissumpen. that it idmanion the outs and has its leps and tabe
# and his prive is and "forgicides
# faith, an
# themsest in only stand that
# thore are in the part itselfs tooker s
#
# ----- diversity: 1.2
# ----- Generating with seed: "s end;
#      a wizard wrought it, he the "
# s end;
#      a wizard wrought it, he the it, mostens alis fare if
# to strang catess itself--thor (in theys so dogaits a flute vainstorey!
# e4flymnisesbsention to
# in
# herea,
# "has been obceapation wisted the good that
# the gails to un lanks" immedismbod, (make
# comrtate, only fool, and deuponde. lew reccilasely: the uncsraptefuly, now at toge? in,
# ressess of pri2cted coachely
# in almoste" to man
# stole remote isnegnest: s
# hard, hir skorning eut a
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.5502
#
# ----- diversity: 0.2
# ----- Generating with seed: "ius for war and conquest, and made its f"
# ius for war and conquest, and made its farth of the such a comprehens of the conditions of the constitute in the such as the consequences of the such a principation of a stands and such a satess of the such as a still as in the religious and such a conscience the such a comprehens of the problem the such as a contempt the such a stricted and such a strength of the possisic of the concerture of the consistation of the such a comprehens o
#
# ----- diversity: 0.5
# ----- Generating with seed: "ius for war and conquest, and made its f"
# ius for war and conquest, and made its from as a metaphysic of the man in the conternate of a commanity that they are here to some possess of all the conquestion and in the origin of all the sentiment and was as in the such as the light for the heart of stands of the origin in the such a contempless of the constitute and instinct which i have become a allow, and contens to a condition, and for all the suspect of the can so the prist as
#
# ----- diversity: 1.0
# ----- Generating with seed: "ius for war and conquest, and made its f"
# ius for war and conquest, and made its for spemlic enrects the poin pusside agows iate after superstity it was inmonty on egoid alead
# plama of all taces and man. there hore thet the higher.
#
#
# 93. flact"
# as the laberate certaid yne? hour rests away whan ,agen
# "suited a fiff con emit. hihh as a fearsts, concerned as "effomentary, deseam and its largly long of orfact and in this the vartions.--ever to be agratific if and for had xedue? wel
#
# ----- diversity: 1.2
# ----- Generating with seed: "ius for war and conquest, and made its f"
# ius for war and conquest, and made its fommus inflichs.=
# greath--must of all therot
# partic continctening or, (just himself have compused can ke by neeved, fell whould beoms morar
# the
# serrt of these old do it
# necessew, duton eithal, will now interrof: but
# in all agre begious ricism
# of specices! if icve longen, as intercerorial whom. curtter,
# true ioques natume, as
# hinks are byer caurisisa-recorless
# enconour mach
# forms yimacyly of samy wi
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.5041
#
# ----- diversity: 0.2
# ----- Generating with seed: "es on the boundary line between this
# wor"
# es on the boundary line between this
# world and the restrated the religious and the world and the restrations and the strengthing and experience to all that the restrations in the and in the and and the man in the and the still that the religious and the world and the will and the would be such a some and existence of the in the world and the more than a present and the world and the finally that the philosophers and the distranted that
#
# ----- diversity: 0.5
# ----- Generating with seed: "es on the boundary line between this
# wor"
# es on the boundary line between this
# world with the
# procisely and substives of else the other we art in the will the in the passions and sool and interpretantifical and the world conseral to be as the the danger, for exception, and
# in that some consequently they are always is a south that there is a new in the still as the believe god the some philosophers and in itself of chance of such as the will as the heart in the preachess it is t
#
# ----- diversity: 1.0
# ----- Generating with seed: "es on the boundary line between this
# wor"
# es on the boundary line between this
# works
# of
# questionsuals tactestance no only timaiom; is and , freto mind of bacing to plays it:
# men for accod thevol.
#
# as the our subsents are fee timation slaves even tradrificed-mowe one country, that
# he happiness has artion. heing. in inter that those doce,
# sefies eternateved reverence to bey erron
# thus
# supoctined that his as ethicies. could for among we for such of
# manwhowar"s which the eronage in
#
# ----- diversity: 1.2
# ----- Generating with seed: "es on the boundary line between this
# wor"
# es on the boundary line between this
# worls, doy of oud, are woulatiful courses, the oursionism pearm. alwayspainard lostiant supothe upges its sual when wrotuch, but
# defticant nartess,
# heardotly so whose indaicttel, "pposed in" they is plants to the fhee-instiedly any been manned in mooustism: .fo sup away to godanaablishally, even
# taitious is to hom has longs thysedly
# swholating,
# them doefical end, has irt arounor most prusties
# iuble o
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200285/200285 [==============================] - 121s - loss: 1.4774
#
# ----- diversity: 0.2
# ----- Generating with seed: "is
# most difficult for us men of the "his"
# is
# most difficult for us men of the "historic of the possible the the subtle of the sensibility of the still which the sense of the present the sense of the present the proper of the still the strange that the possible the sensation of the still which is the present the spirit of the strive in the most and a thing the world of the world which is a soul the sensibility of the present the constitution of the historical in the strange the
#
# ----- diversity: 0.5
# ----- Generating with seed: "is
# most difficult for us men of the "his"
# is
# most difficult for us men of the "historions of the future the purstly appearance to the higher and a not ever had and out of such still and prodorantly the profound the the conditions has been the still in still the greatest and the rank which the power of the proud of the conscience of the spirit of the consime that the thing the historical the seedity of the interpret, and itself and
# being that a feeling to the behost and the pree
#
# ----- diversity: 1.0
# ----- Generating with seed: "is
# most difficult for us men of the "his"
# is
# most difficult for us men of the "histimss of the respossition instinct to with with is a swand, in victurs to re;oven.
# afe ricklows and more
# one one ield anythold conference, even heapy is encorndes, sungrest which i say is it the specital in
# whicad is it is pre: which that dream spirits men: the soul fais the prisent imadrling and hand the resolution of whichest the spirit individuals an erencic is the
# wuppetheption of frae, that t
#
# ----- diversity: 1.2
# ----- Generating with seed: "is
# most difficult for us men of the "his"
# is
# most difficult for us men of the "his womines, also--whound
# taute is wand in
# etends our use coold
# mous,
# a
# coum to speechated blind relote, one whoselow--their
# velutah, a arking or or. they filse outtoned, the
# free." "i geption and entawood by
# life, and futhead work begin stoods to the maled, weaknegay urcerticily by purploud gatel their speaked at anotherco-occate rawn, in ioping forthers" in the heriouarismd tood cra.d duesy spirits
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.4552
#
# ----- diversity: 0.2
# ----- Generating with seed: "r displaying to advantage our power of
# d"
# r displaying to advantage our power of
# delusion to the extent the intellectual the strange to the strange to the men the state of the sight to the most and success and the subtle the sense of the expressed to the sense of the same the conscience of the sense of the the experience which is the same to the strange and conscience of the strong to the most to the little the same to the other have to the intention to the subtle of the word t
#
# ----- diversity: 0.5
# ----- Generating with seed: "r displaying to advantage our power of
# d"
# r displaying to advantage our power of
# does there a previction to interess, and in the strength to the interpretation of the extent of a say and a personal rest of the external the will to morality, he will to which is as the case in the desires the most things the proveding every subtle, thought that a proghiss of a to demost to the still schopenhed and state of being to the sort of which the will, gratute of the oarly to be really the
#
# ----- diversity: 1.0
# ----- Generating with seed: "r displaying to advantage our power of
# d"
# r displaying to advantage our power of
# devily on
# dart this occasional may riblilicitation, too-distinity--have too reminsle," they excepte":
# which is to rank, with
# not forces avere and necessereliging seems "it, indomentantatives of thou
# 'the lawpy, not to one seems its fagh appsichthtect anewored it meintagy, it is the most beyartture. the jewicc forming, with hols of the epochiss, is exelusthent: "perhapss in the furtre type "when the
#
# ----- diversity: 1.2
# ----- Generating with seed: "r displaying to advantage our power of
# d"
# r displaying to advantage our power of
# dankinations into his goir to whield to a
# god meanty or mid, thinks--an asslies lafter, hereamy that a rejote.: beledentward,ly every givet
# some
# must have hered it
# is predecty un doge that those is invalueutated in intesequene, dischery attempt (therebyarof owh-gueusy
# resesvate, the perior stasds.=--he dream. or subple "fe
# chindalituer andhence on meservails way
# been divelifidatour on itfer recures
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200285/200285 [==============================] - 124s - loss: 1.4373
#
# ----- diversity: 0.2
# ----- Generating with seed: "a gross mistake, therefore, when histori"
# a gross mistake, therefore, when historical contempt, and the stranges of the strangest that the stranges to the strengthsments of the strengthsments of the stranges of the sensually and in the standard the strengths of the standard in the such a standard to the world and consequence to the made of the strengths of the strength of the such a probably the striving that the probability of the strength of the sensuality to the strengths an
#
# ----- diversity: 0.5
# ----- Generating with seed: "a gross mistake, therefore, when histori"
# a gross mistake, therefore, when historical condecting and regard to the man which we stronging of the the man in the striving the the stantain, in the words in the port of all inferroble to so that we strength of contraprest even the same probably that the origin of life and into the life himself, and one should be partule that it is a standard the philosophy, it is a because the prige to a special individual consequence and the sense
#
# ----- diversity: 1.0
# ----- Generating with seed: "a gross mistake, therefore, when histori"
# a gross mistake, therefore, when historism unperfounds?
#
# the
# happiestined mentented corruditus one strength his fears, could for colour: more
# non-another, or who string to stay it in its telence out of the wagnests that to the one's heinch
# immenociess perceables
# fort and indeedwanned civilizioy and hembeeth.
# the sentiment to his lichs of man,oucupated his
# ething metaphous
# sauct, yet what is noed--the "spirit to this greatest. yet as
# a g
#
# ----- diversity: 1.2
# ----- Generating with seed: "a gross mistake, therefore, when histori"
# a gross mistake, therefore, when historion
# she such aven a lave spirit.
#
# such addowming andsespedate nomuses.
# these cale
# spicue in weight
# certainty unexhast, shree, levitsen, did of the soro---aloness, to
# being histered; there is noble well
# fepts and selisshing of
# "frais, futen, and shenegring signivilen, at the unrefertanise capabje for ?
# if the soen indeed in thus e fear
# itself
# over the presuarct
# and are it troud
# such rachep--more jus
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.4256
#
# ----- diversity: 0.2
# ----- Generating with seed: "ined what
# wisdom there is in the fact th"
# ined what
# wisdom there is in the fact the moral in the sensible the strange the sensible that the particular of the morality of the manifests and promism of the process of the moral of the sensing that the process of the morality of the considers of the strange the process of the moral of the moral of the moral and the subtle the species of the moral completed the moral and spirit of the morality of the process of the process of the con
#
# ----- diversity: 0.5
# ----- Generating with seed: "ined what
# wisdom there is in the fact th"
# ined what
# wisdom there is in the fact the strange the same all really that the names providing all that when a substing in the fast in the logical that the spiritual that or the part which would be high upon the more comparious morality which, and as the man is only for that the find the shuple of the present of derising and experience the self-tovers of the
# possible where the maltifice of the man of the conceusions of the action of lif
#
# ----- diversity: 1.0
# ----- Generating with seed: "ined what
# wisdom there is in the fact th"
# ined what
# wisdom there is in the fact the (as hhow eriorite with the antirapr than the notmotist in not not be trywed us
# to its wind, actual tradigious. these satisfigurs
# to him providual erron-tructlty to there will every nong has
# being hind of the dicond secrines his couder the greas as reilld without find its
# and nerdedly, for nature,
# who could finadious and nevel innod could want--far inmen that
# the owing to the wat"! the strength a
#
# ----- diversity: 1.2
# ----- Generating with seed: "ined what
# wisdom there is in the fact th"
# ined what
# wisdom there is in the fact this madenuch love
# for their dailetory serd doubt he shealy have ear vouthess); anourals becomes of flussd cupary
# qualitu face that
# grambly,
# for cannothge
# the highes; and iuhiments into be its
# lovesmed
# appulfomuthism has us their persons whether genmimalel.d manifest whatimsl you,"s "hagness ranking had"" snceove renawanl," he chillery,sniccul.
# here co poland it is the complays ledes, whas that muth
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 200285/200285 [==============================] - 124s - loss: 1.4148
#
# ----- diversity: 0.2
# ----- Generating with seed: "t should always be kept up in some fashi"
# t should always be kept up in some fashial of the sensued and the sense, and the sense, and and who have an existence of the sense of the sense, and the world to the sense, in the soul and the transled to the and also the sentiment of the sense, and the sense, and the personality of the sense, in the sensued and sensual profound, and an end not as the sense, and the sollation of an all the sense of the truth have the deed to the sensual
#
# ----- diversity: 0.5
# ----- Generating with seed: "t should always be kept up in some fashi"
# t should always be kept up in some fashial the case and the circumstance, and he decision and the most fine to the present, a substances, and which is a contrave is so the probably one of the sense-of the sense of the individuals is in the high the sense, he most an an another, and himself which sensual particulity of perhaps of the highest and as have been time. a great century, that is as freveen that is impering in the sensaician way
#
# ----- diversity: 1.0
# ----- Generating with seed: "t should always be kept up in some fashi"
# t should always be kept up in some fashial; ever even, that all the same naturally
# about the one" more
# cause are regarded
# colors and taste mivine imanciblianns pant then forfinunc, passible. the choiles in easy of
# emoturty grounligismsion, an the fothing, mother-estimates, beings who
# this
# painque conside as caily especies to kneeles
# edow pathers.
# a. every existed muliount an reilive-piounce to the
# people mrdinicted establish for
# even to
#
# ----- diversity: 1.2
# ----- Generating with seed: "t should always be kept up in some fashi"
# t should always be kept up in some fashial-covers, inkeen le
# rercoplishable upon ulser all thing.! it puriation it is to everything eapit, inspfeedent of "boing, justify, and cannitile
# known herselfament without. as perhaps. to philosopher--backing. even
# intalen any centurys in natuled
# about a fear power sachance, ? deern
# wo and
# contradictaly ohers, humours in trud and pain" and unctrime
# tractly europeand cessably.--a kneel depets "thes
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.4063
#
# ----- diversity: 0.2
# ----- Generating with seed: "pathos
# of distance, such as grows out of"
# pathos
# of distance, such as grows out of the sense of the morality of the sense and and sense of the way to the present the present the sense of the word the sense of the sense that the master and a strength, the propording the sense and the word the express the feeling the morality and the world of the something that he was the sense of the sense of the man is all the sense and sensations of the present the sense of the sense and some
#
# ----- diversity: 0.5
# ----- Generating with seed: "pathos
# of distance, such as grows out of"
# pathos
# of distance, such as grows out of humans that the imperponate the sociate the other is decise is all the woman of the essential in the same general and be reality of the god, the concealed and in the same brought the will and first them the good and expensive under the hence one would be wheahee word and the eternal instinctive men beding and something and the religion for a surest all philosophy and subjection of the history of
#
# ----- diversity: 1.0
# ----- Generating with seed: "pathos
# of distance, such as grows out of"
# pathos
# of distance, such as grows out of a kind of human meril shond of
# pains sense. the world, as well, usperity, the "motive other the greaters secret, a many little ethypandenism" we limok.
#
# 111s it--the a
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:63: RuntimeWarning: divide by zero encountered in log
# mong and self;msel exaggs of the prodution of the
# our opinion. fool and conquestion of man": bus to understand a stroke and wiff the sapened was reputed and begre, inverthed of it
# is amitas dorny certale".
#
#                  oo ; men
#
# ----- diversity: 1.2
# ----- Generating with seed: "pathos
# of distance, such as grows out of"
# pathos
# of distance, such as grows out of
# say, myprohe
# german ribarie thas.
#
# 121bat
# free miferce unniguric herely something itarquie, thus. what a fuies
# the her ir wup
# fitly ecielce. mucup"es is not require full
# a
# you which class-trave,
# certain laxe
# wamly threw to the justice at picwurality, now
# self
# realicl
# in human,
# kindious igleod a ;day power live heart," and fre; all "it
# deteriiew or
# accountion faptidation of truth, sufficietism, c
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.3991
#
# ----- diversity: 0.2
# ----- Generating with seed: " a loud and
# virtuous outcry when the pro"
#  a loud and
# virtuous outcry when the probably in the sensual the englishs and the consideration of such a strength of the soul and respect to the probably the spirit of the spirit of the fact to the spirit of the strength of the strength of the superstitions and person of the sensually and strength of the specially the consideration of the sensually and the soul of the spirit of the sense of the sensual considerations the devilent the p
#
# ----- diversity: 0.5
# ----- Generating with seed: " a loud and
# virtuous outcry when the pro"
#  a loud and
# virtuous outcry when the problem in the strengthent and strength, as all the spirit in the soul spectary that also its new philosophers and the strange and the spirit but the caste of the soul cause this freedoms of the morality, the command in the and sympathy of the cause of schopenhaus consciously striving and respect to a sympathy and devils as an in the cold that it may be has more and sentiments in the nature. the impe
#
# ----- diversity: 1.0
# ----- Generating with seed: " a loud and
# virtuous outcry when the pro"
#  a loud and
# virtuous outcry when the prouds. how a purentged everythrer
# alpear the ongaced in the sum and
# cively men: when it delechesing, its opposite in the echar, and refinerty against on the newadous, las to door and to that only assled to be nob henie to spite as these sensuaraties onsingly that had and more in its, not are order to value of scretaimity, the
# bad; and
# musit or modliliation.--whoever, say, from the its explosation an
#
# ----- diversity: 1.2
# ----- Generating with seed: " a loud and
# virtuous outcry when the pro"
#  a loud and
# virtuous outcry when the profoundliar philosophy-isbally deecies, happen more me. ne
# distran spirit; to
# doke semble aboutsited worlouitficaltivalness, something
# under
# to that the own philosophikative itself ney kind of develop age, gaybwainnceshed upmontily also treasis man does werely fine. betterces. of the wormilative entivid on stabit is also to be eligination! iabem do
# notigiars, yel buthies
# in concentian pressumptessit
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3918
#
# ----- diversity: 0.2
# ----- Generating with seed: "ery great,
# nevertheless; their combined "
# ery great,
# nevertheless; their combined to the problem of the strange and the sense, and the strange the sense and interpretation of the strange and in the strength and will the strength of the strange the fact is a stranges and who have been the world, and will be complexten, and the strange and will the strange and the sense and the strange and interpretation of the strange and the strange and the sense and the strange and in the same
#
# ----- diversity: 0.5
# ----- Generating with seed: "ery great,
# nevertheless; their combined "
# ery great,
# nevertheless; their combined to seem intention, and who are all that the world which the morality, the strange was the only a strives to be does that the artists and same will and in the sense of distractles to his order to "be unconsists of the highest also superficiality which is the superior of the latter had the strives the problem of talking, so lather must be processis, and its every something that it can be every befor
#
# ----- diversity: 1.0
# ----- Generating with seed: "ery great,
# nevertheless; their combined "
# ery great,
# nevertheless; their combined same, in every bloomal, and supernal shoild the bad, is more, however no way to still. the origin--that is when was to prile is partical that, are
# thought, on the thing
# of doditional doing who desire pious
# too, a stree hateline like op
# too wished to one, men and another, the likes valces of philosopherth acts in the demoral dorn if the lauses and not an effect of a god the first "calliar that to v
#
# ----- diversity: 1.2
# ----- Generating with seed: "ery great,
# nevertheless; their combined "
# ery great,
# nevertheless; their combined maintenon" can respociss and prolitices is conditions enecy at prigob", howlod but this personalistic
# "more against did must
# we that here insires all willowest-ilicably laskingn obares? othing according to willesses
# and us-blevect and concerning is us, those is disunagain, out ellee, and that
# this
# "eyes oft
# own appigssc! how them, wert casongaries"--the cases and his god, value,, and
# membies
# scien
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3849
#
# ----- diversity: 0.2
# ----- Generating with seed: "dst
# of hellenic culture, with the atmosp"
# dst
# of hellenic culture, with the atmospiating and almost as the sense of the sense and a strange, and in the sense of the sense of the sense of the sense and interpreted to the and almost as the sense of the sense, and the problem of the progress of the sense of the conscience and and almost also the self-restratics and almost as the sense of the sense and artists and almost as the same strange the sense and a sense of the conscience a
#
# ----- diversity: 0.5
# ----- Generating with seed: "dst
# of hellenic culture, with the atmosp"
# dst
# of hellenic culture, with the atmospiating, has not already the same personal than that the same possible. the light of "position and the artificisted and the danger the processity as in the fact than that superiority and experience for the conscience in the soul in the will in every faith--of the thought and with a side is so occasion of the same philosopher comprehense, in the manifested to the morality the fights of the proper a
#
# ----- diversity: 1.0
# ----- Generating with seed: "dst
# of hellenic culture, with the atmosp"
# dst
# of hellenic culture, with the atmospy well be
# prevomences
# becaused to enguide
# "unelse whoure
# mean of obto be it not for the dering of it, more, be clovers. the more--iught nature of friend which as conprised, atmoning laughism, seasion than in queste martist with share to christian serves onficged oars. only in the as utter convictions--if there is lavofing
# to fund, and des "is virtues, and wors, not serious
# plarrumoni the law was d
#
# ----- diversity: 1.2
# ----- Generating with seed: "dst
# of hellenic culture, with the atmosp"
# dst
# of hellenic culture, with the atmospiared use 'the will mislut of
# magnificenta miscised, grate vove logically (allsedd error a evolutions, all the isgenimed thee? them.
# noste, that grank hims own imagin wher circumstances can what he calle than
# meanation, almost acceptial whatevere, but would belout
# indice
# plunt perceiving, possibly an, the
# sensed guigings of involves its
# pleuponed
# without  stous hers and all. novenured.
#
# intoe diet
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3803
#
# ----- diversity: 0.2
# ----- Generating with seed: "nd, who
# involuntarily communicate their "
# nd, who
# involuntarily communicate their standing the standing to an all the contrary, and the morality of the prospriess of the sense of the standing the contradictory and and in the streatness and as the sense of the contrary and as the philosophes to all that is the standed to the same possible and fact is the possible of the morality and soul that it is the subject of the standing to a substance of the sense of the strange, and in th
#
# ----- diversity: 0.5
# ----- Generating with seed: "nd, who
# involuntarily communicate their "
# nd, who
# involuntarily communicate their good cares
# only how could and not a statume and more out of the preachess for instance, and in ordery and answer. it is a philosophed the tone"--something
# of the sense of designated and perhaps ill the strain or a new sollances and rests or the contrary and authory of the soul of the man and because that it is not the subjects and secret and difficult of the contradictorily and sense of all a life
#
# ----- diversity: 1.0
# ----- Generating with seed: "nd, who
# involuntarily communicate their "
# nd, who
# involuntarily communicate their flow. yeulfully suffer intekemente intercibyles
# light--but itself: there golder the developmen serialful of this is
# notyy or is an apirris and fight possesserous
# charachen the
# "life arf--hell to this all to the same made this becauses somelimedness exciate himself. form is tof a swreat, to
# owing
# modes himself, and remackel of europe; as the time as so much yus to all how harven in europe
# arous dem
#
# ----- diversity: 1.2
# ----- Generating with seed: "nd, who
# involuntarily communicate their "
# nd, who
# involuntarily communicate their amigan timace how when it will does not to say the remain well
# sads--but from all authorfelsed, upiliarerorst.
#
# 22i
# y of the waste gunary
# indo to be,
# burd if
# it is not everythiof into to schopons the us
# exceptude as
# anarbly, depthatings., to finesl" (and so wounds wit. for the "man has not makes of human
# may almost  pjetishized something, and it are winaponuther must tookness absolute cha
# rymasse
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3750
#
# ----- diversity: 0.2
# ----- Generating with seed: "in your pride you wish to dictate your m"
# in your pride you wish to dictate your man in the procession of the profoundly the conscience to the procession of the procession of the self-conscience of the same will be the profoundly the profoundly the soul the procession of the same as the procession of the self-consideration of the self-rearing the procession and former the tradition of the soul of his soul of the soul and as the self-consequence of the world and same more and in
#
# ----- diversity: 0.5
# ----- Generating with seed: "in your pride you wish to dictate your m"
# in your pride you wish to dictate your man are as it is the so longer to distrasele and one's more and conception of the philosopher, the distrasted such inspire creating the discrised and consequence of the self-own and awaken nature and proudor of the one as the world, one then the fact the sense of consequence of the personality is demonstry there is according to the formby of human the tranvent of the really the superiority and well
#
# ----- diversity: 1.0
# ----- Generating with seed: "in your pride you wish to dictate your m"
# in your pride you wish to dictate your made objectures result of o blames and the regard to the class of sancion
# to harpochity, closes heamest agredand, as the answer, to it, with comprehends
# for what men a need the more than the to engent reing evidence that, almost does not, liberaut" very necessity to their day cases of frightunhecl, which pensimismate problem, when such
# special commatific modern more danger
# of rely turn cannot he wa
#
# ----- diversity: 1.2
# ----- Generating with seed: "in your pride you wish to dictate your m"
# in your pride you wish to dictate your meftals; functionssly victue. in ittenw insignificatess noble: just spitomed slows    e above to is ethicling, that which, them, "amonony insustens
# through nature
# modes of a gapt in one."
#
# 268. as
# but re:ds occasions instancetend, but but, sunsumod, "because towardss which "the heartion? "man--
#       nationization.
#
# as a bsse-dives-barbarable for himself as greatesion-in--this error of lers protesm
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3710
#
# ----- diversity: 0.2
# ----- Generating with seed: "t ye hear is rome--rome's faith by intui"
# t ye hear is rome--rome's faith by intuition of the sense of the more constitutes of the sense of the still and standard and sense of the sense, and the sense of the stands and the sense of the constitutes of the man is a state of the stands in the sense of the assertion of the sense of the stands and interest and about the sense of the senses and the conditional and sense and the constitutes and man, and who can be something in the sen
#
# ----- diversity: 0.5
# ----- Generating with seed: "t ye hear is rome--rome's faith by intui"
# t ye hear is rome--rome's faith by intuitions of the considers, and we are
# all still probable every more end motive of the same philosopher as the morality and about the experience of the highest the rund a problem of the power standing instinction of the more amid of the general man are all the
# most constitute of before the special senses of all that the more course and development and constitual strong and also the sensations and cons
#
# ----- diversity: 1.0
# ----- Generating with seed: "t ye hear is rome--rome's faith by intui"
# t ye hear is rome--rome's faith by intuition, betray in something or a curhef: how howed to us. and conmor
# the emotion knowthyloo of desension which bele
# eutions in itsige: eaqjeurse their weate, he we does not not interpretiness of
# the woman, very walling. it is not
# aimsative as one into
# his betreaged without unnive world
# probable
# book
# people be sow howeverere, therein, reverse. he
# could be soble and
# despatuable that it is much our por
#
# ----- diversity: 1.2
# ----- Generating with seed: "t ye hear is rome--rome's faith by intui"
# t ye hear is rome--rome's faith by intuition (say: . and
# rarealy intoodle indeed as wondsten" really, as its
# instinction," el(
# its
# idea had rul. and
# parttable compuliginess of picture on the interrogations
# cruendy confine but
# the civilizations
# is a
# delicate ringun;
# afto instinction, its domuness: or panaatidly--and not quietment--there are sitise as cruticning, ares betwee
# one, areinfament, grient
# also ridden.
#
# houte
# gorial century: acc
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3672
#
# ----- diversity: 0.2
# ----- Generating with seed: "ccurred to the
# mind with reference to an"
# ccurred to the
# mind with reference to an instinct of the superficially the present of the superiority of the soul and a souls the conscience that it is the present of the presented the contrave in the presented with the sense, and it is the spirit of the substance of the superially the present of the presented the conscience of the conscience of the world we was the present of the presented the traditionally the presented the superially
#
# ----- diversity: 0.5
# ----- Generating with seed: "ccurred to the
# mind with reference to an"
# ccurred to the
# mind with reference to an again and it as a sulse and relies in the
# same commanded with a fear of the far of action to the individuals of the contravely the great presers of the meaning, as a presented and the traditionally belongs to the presention, the sel what it is present of the sentier seems and more
# supposed with the deliving as it is its chreaced of the
# free spirit of the death with the superiority of man is the t
#
# ----- diversity: 1.0
# ----- Generating with seed: "ccurred to the
# mind with reference to an"
# ccurred to the
# mind with reference to an   indep present stronger other "man, "will it, but the tragede i aduw-li.
# not hever the lawsficioust. how
# noticious their here they in a free one's still every owind to their
# nature, the con-cometies of natove glorterd and
# liteman as botrel than
# the presebmseling than the burdeus to fiil human
# wholpen only that more passian one pathed that
# it isby the painfhand-ruld also ye
# jerely well ioxlicged
#
# ----- diversity: 1.2
# ----- Generating with seed: "ccurred to the
# mind with reference to an"
# ccurred to the
# mind with reference to antinest conceptious
# defes-that onitiely,
# who commond." knot, and taken agocegative
# in the geniman does many
# litts vostrime on, plutwant, from
# supersianly, and ow diame initions at widimy that
# is all the because
# eyes only at lose's as too lupness, and
# must ont schection wherever, as i not
# elseess without foriase,,
# upon skepticist, though it wis in
# opposing europeans
# with morals
# incaral wiler,
# that x
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.3650
#
# ----- diversity: 0.2
# ----- Generating with seed: " prompted them to keep apart and outside"
#  prompted them to keep apart and outside of the same one in the same than the conscience of the sense of the same present and presented the present the same problem of the same out of the present the sense and sense of the condition of the special and will a philosophers and with the same object of the same one of the strange--with the speaking the same day to the organized to the same recustoge of the sense of the same and all the stra
#
# ----- diversity: 0.5
# ----- Generating with seed: " prompted them to keep apart and outside"
#  prompted them to keep apart and outside of a discipling the consequently therein a thing him--the beleel to the inspirious even to be instances and self-destruction and such a probably a such the will to the strength of the europe of the present the first also the good and interpretation in the conflict to a present of the child, we are the problem--order, the conceptions of a scientific of the conceptions and feel the desirable of the
#
# ----- diversity: 1.0
# ----- Generating with seed: " prompted them to keep apart and outside"
#  prompted them to keep apart and outside and dreadful, pour ory
# and dares. consequences
# strictary does nowadays has itlesse brearten in conscranime our physitiestity; we knows,
# cistual herctories which sacrifice,
# things, they mixtfed the proftuite one would like our essentially,fuction, stourm him a four pointion, alropherate a conscience yile ideas of the clouptest "in any science
# trulening and take there is thereby suggrtientand," men
#
# ----- diversity: 1.2
# ----- Generating with seed: " prompted them to keep apart and outside"
#  prompted them to keep apart and outside peening even it enhale sciaral durige themself made towantung, at are exdeptaluations him--as
# .
#
# mour speaking betow": we doater: they be means to they than known it be everied, finally instinct yet his lie "oi hablous, the run essension atherianity, autmor," when, utter of thest--we gregative and really among the goodness hand of
# kind, which are floon, ever to brearatis of the kind;? voluntion;
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3606
#
# ----- diversity: 0.2
# ----- Generating with seed: ", but
# always in a profoundly personal ma"
# , but
# always in a profoundly personal man in the conscious, and the progress, and the world to surprises and the sense of the saint. what is the same the superstitions of the same and and wholly the sense of the strange of the sense of the progress of the personal and about of the superstitions and more and such a spirit of the constituted the sense of the sense of the sense, and whoeling and as the conscious the spectary and and about
#
# ----- diversity: 0.5
# ----- Generating with seed: ", but
# always in a profoundly personal ma"
# , but
# always in a profoundly personal man of man than the older to the resist the conscious the salition of the spectary and everythish, and far more spirit, and as such example in the form of the fundamental conscious them in the spirituality and and religious, standard the spirit of does the
# end, and about the same understandsed with the logical and devilud the belief to the fact that is a man is in the conscious the self-denoun probl
#
# ----- diversity: 1.0
# ----- Generating with seed: ", but
# always in a profoundly personal ma"
# , but
# always in a profoundly personal man.
#
#
# 11ttanobauct amugans, as but there even in his master of "signatificic mares the whole part. welarise, and most
# certainty through. naturable for everywhered, what even manshils
# there apdown of
# nasis untacre of . and suspiciousne. it almost concelce, this, and does not in the future of
# musicial."--can least as
# the foundance for the individual that
# determing or comeursed, then; the senses accou
#
# ----- diversity: 1.2
# ----- Generating with seed: ", but
# always in a profoundly personal ma"
# , but
# always in a profoundly personal mansly of notion ver
# desire of whom tundwruld would -attew to our merely any powerfulness to cater whe long from the tuseness carrishowy truall a tupprication and eurmpreal, whater is lightering, his masim to apophoryled for sacry
# are the most seffeved,
# a raced as to
# revolssay
# cature to becauses. the of. heaving new, "germandes:
# to
# be deeshs when the conclusioning, reade, -general growth of the engu
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.3587
#
# ----- diversity: 0.2
# ----- Generating with seed: "rtain
# circumstances, her health, her sel"
# rtain
# circumstances, her health, her self-conditions of the soul and conscience of the states and conditions of the case of the world of the sense of the self-conditions of the same philosophers and the self-desting to the same philosophers of the sense of the sense of the self-destined and and away and the sense of the same philosophers and above all the strength, and the most strongest and sense of a soul of the same despession of the
#
# ----- diversity: 0.5
# ----- Generating with seed: "rtain
# circumstances, her health, her sel"
# rtain
# circumstances, her health, her self-ridled charithing also the conferency have been capacity in the exceptions of the modes, and the habits be surpression is a case the sense of the shappower, and harders of the age in a community it is a feeling of the soul, it is forget any things in respect to the truth--what are the to stability of the consequences and
# with his master, and read the exceptions
# of all the being and the dangers h
#
# ----- diversity: 1.0
# ----- Generating with seed: "rtain
# circumstances, her health, her sel"
# rtain
# circumstances, her health, her self nowadaotly
# with fith forms which doeling--but consicifulnes the exception we repose the "incring restons in the
# opinion in the considerances--mising
# word
# as it
# noters which were the ideas, sacrifice wishe of dimble read
# toonerswreptest becient is tofjvertsd with regard not
# a!
#
# fountohest
# the short""--and
# uffoversd cannot appeared hitherto not teuss of contuspogism self-modes of him; not have pr
#
# ----- diversity: 1.2
# ----- Generating with seed: "rtain
# circumstances, her health, her sel"
# rtain
# circumstances, her health, her selfled tastorwymrne, himself, or.
#
# mwrëhnt too, they suffering radically,
# it is portion to thingsity with europe
# and eye queshih akisshiws things?
#
# whither made
# sorramedness
# deing face he pain butd without oby would frection must cantharafy how
# mores otherwise,
# and reffectrouses. even throughoue are such gavity,
# that
# fights
# for unfiving contemusanly and wild to a man it was "themselves activaligsms,
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3541
#
# ----- diversity: 0.2
# ----- Generating with seed: " that at present
# one recalls its sixteen"
#  that at present
# one recalls its sixteent of the man is a philosophers and the same philosophers and the principle with the same philosophers of the super of the morality of the sense of the same stand and the same success, in the for the great strange of the principally and the thing the action, and the presential sense of the state and morality and the super of the sense of the contrast and astumical such a strange and the same man is
#
# ----- diversity: 0.5
# ----- Generating with seed: " that at present
# one recalls its sixteen"
#  that at present
# one recalls its sixteent the little in this fine charis of the the comprehension of the traditional many thing of a surthest and such a beloods that the conscitute saints of the conscious of the process of all and delusion which he are the condemns, and success of the sacrifice, the midds, a great essentially for the fact the friends, and the daring to have which a philosophers and and cost of call the one of constraint
#
# ----- diversity: 1.0
# ----- Generating with seed: " that at present
# one recalls its sixteen"
#  that at present
# one recalls its sixteentous of acts vally or cultuliy--there is only
# nothing and in the problem stituble
# heads that our mind loftee of christian bahk itself--before such ogison, onder in maladiess of moral whouthsead everything that has hescess with fathers. in attain of
# ciseration even fortuness, have the is
# we soul--namely which prively
# sal arvatogates. he have not stands ostibitler, seove fundome to us! the becashe,
#
# ----- diversity: 1.2
# ----- Generating with seed: " that at present
# one recalls its sixteen"
#  that at present
# one recalls its sixteent of they a impulse un
# ...
# alotin
#
# --------------------------------------------------
# Iteration 53
# Epoch 1/1
# 200285/200285 [==============================] - 110s - loss: 1.3603
#
# ----- diversity: 0.2
# ----- Generating with seed: "e jews performed the miracle of the
# inve"
# e jews performed the miracle of the
# inversion of the most suffering and the most actions of the heads of the superstition and the world more and in the same may be the superstition of the world of the world of the stands and also the most also the spirit of the possibily and also the the a superstition of the stands the consequently the problem of the best what is a body of the stands and in the same wishes the same and the consequence
#
# ----- diversity: 0.5
# ----- Generating with seed: "e jews performed the miracle of the
# inve"
# e jews performed the miracle of the
# inverse of self who was the most also the highest hence is not be superstition of sinces is all the philosophy and extent and imperion of the "not itself all the form to the present the will, as the highest an avities, and the "bad" with such a philosophy of his false, such a not what experiences of the regred this in every every misunderstand, such a good subject to the hand, has been the type at all
#
# ----- diversity: 1.0
# ----- Generating with seed: "e jews performed the miracle of the
# inve"
# e jews performed the miracle of the
# inventy--is correse regardes, who compresing
# in responsibility, for fear has possiman of
# which all pricises too you
# from men itself
# ards of the spirit,  will being what have a being for his unof
# case at sperely every long best, at the a stands respect to recipocs of hed a
# greets always be only also would be really changes that a belief. he art accountian women a vairs,
# and its. they is even too mood.
#
# ----- diversity: 1.2
# ----- Generating with seed: "e jews performed the miracle of the
# inve"
# e jews performed the miracle of the
# inversing contrude
# or would positionce as bae errvoums
# but
# from this
# tribened-in
# vollent deviat could, joy: a percise nobelinism, or one honest hestly to the
# kind time. chorotidas the "mabor in the
# favoundd
# belity intimanth thus always," for "skeptiby
# arrenedtament it
# means
# of their impresiding terhuent, the lems as a point and magnifalt conssquites all legoc
# ticent circum is inschnouchings of puttish
#
# --------------------------------------------------
# Iteration 54
# Epoch 1/1
# 200285/200285 [==============================] - 122s - loss: 1.3524
#
# ----- diversity: 0.2
# ----- Generating with seed: " conscience, the
# idleness of olden times"
#  conscience, the
# idleness of olden times of the presence of the first the spectap-and the present of the present to the present and sense of the consequences of the present of the standpoint of the spectator of the present to the present to the conscience of the spirit of the present and soul and self-delusion of the spectator of the present of the consequences of the consequences of the standpoint of the same delusion of the present to
#
# ----- diversity: 0.5
# ----- Generating with seed: " conscience, the
# idleness of olden times"
#  conscience, the
# idleness of olden times and tere--perhaps the strange, and disturze and the finer to the delusion to the habits the first the strange, who are the free spirits of value of holy of a new of all man of the repulsure is the one is a world, and as the most rule not the results to so the present and considerents of the world and the imperious the confinus of feeling of the spectators of his life which considerents of probabl
#
# ----- diversity: 1.0
# ----- Generating with seed: " conscience, the
# idleness of olden times"
#  conscience, the
# idleness of olden times
# no qualitions to the on willing inafecuvque in skre imbear no privily
# the struggle
# sacrifice of former accordunes to notes to pression, about it! how stet world-soun-" they world, is always men, hatm, so thereon defineder of the whole even
# one sempling
# civilitior has religiors and living this history droughty or who harden: the salf" and certain possibility--himself another observation to the spi
#
# ----- diversity: 1.2
# ----- Generating with seed: " conscience, the
# idleness of olden times"
#  conscience, the
# idleness of olden times
# but to us: seek and
# beion: "another
# thic is a partist, wish to hon," redirers and organce of taste among
# o(w(quite
# fortines
# it
# pairability of beitne, but shuscess and
# general strengths of an evenlunt refined, itrvoring
# doiny perwfined is arishum of all other metavhy as chies. we have reducted
# clevers to ba tlase"--plets reasonows, this
# extense: ided by such as to phil very domentation, befrome
# an
#
# --------------------------------------------------
# Iteration 55
# Epoch 1/1
# 200285/200285 [==============================] - 123s - loss: 1.3469
#
# ----- diversity: 0.2
# ----- Generating with seed: " of dogma stands with sad and discourage"
#  of dogma stands with sad and discourage of the sense of the spect of the subject of the sensation of the soul in a conscience that the principle of the subjection of the sense of the simple the more and the truths is a present of the standaring of the surpreas of the subject of the subjection of the translation of the subject of the subject of the subquesticned and the sense of the same responsible and the present of the principul and
#
# ----- diversity: 0.5
# ----- Generating with seed: " of dogma stands with sad and discourage"
#  of dogma stands with sad and discourage of such a possible as the love of conscience of the same cars-race and here it is the true, and sensations of the truths that is the sensuality as the individually when the democrates or individuals that the truths is easier that it who was personal or the subjection and inclution of the right to the strength of the contemporated itself as the truths is a protection of the truth of the implicitie
#
# ----- diversity: 1.0
# ----- Generating with seed: " of dogma stands with sad and discourage"
#  of dogma stands with sad and discourages. it
# werth artias like and phare overchand,
# duling
# the community even shopt and drever. there are soul! but new respect to thou, ye farcibeness of falsion of a detlication and a one call men are in general
# and all reference.
#
#
# 01
#
# =is
# presents and of princip wear is nowarnsing will
# say. of mechicus in mart
# of a raided
# man, a mruty, errons from the
# dirigian just learned present, is our swave sinu
#
# ----- diversity: 1.2
# ----- Generating with seed: " of dogma stands with sad and discourage"
#  of dogma stands with sad and discourage as a moment, yours any stantion
# of ralvoming, tire call appear,
# what there, it is now question exception. christen, of vesh aimmen xo, the develops hammobuozalty--distoped i conductionalness--never knpoans that in the laugore. worses", that as by unconception was
# neling cmar--and can :
#
# --------------------------------------------------
# Iteration 56
# Epoch 1/1
# 200285/200285 [==============================] - 125s - loss: 1.3552
#
# ----- diversity: 0.2
# ----- Generating with seed: "quant il est le plus religieux et le plu"
# quant il est le plus religieux et le plus of the man in the strange, and the spirit of the sense and profound and the same contrary and the sense and sense of the prosture and the prostical conscience of the pression of the influence of the prise of the ordeal and all the pression of the states of the consideration of the contrary and the sense and profound and all the standards to the prostical called the time and all the pression of t
#
# ----- diversity: 0.5
# ----- Generating with seed: "quant il est le plus religieux et le plu"
# quant il est le plus religieux et le plus of the prision of an impulse that it will to the heady, are mude of the striving and scientific men the own part of the conditional and sound and thinking of prevale secret conduct and sense-insumble in all that is a man to be cal the prostically than here had indispate the
# fact is to the belief that the logical significent than that we have any latter into the sense and and the man and prevale
#
# ----- diversity: 1.0
# ----- Generating with seed: "quant il est le plus religieux et le plu"
# quant il est le plus religieux et le plusian, guilt
# the light of the man if the humanies. aswerd of rank it was then else what   the
# judg men an-bed of
# sorion of the dog to immediate this mithing for with anything in the nature. and bold
# action and soining, with the incorrminater to infledinable interprocrate in give vost our in belief in lead there is may be unfair factquican for also
# speak, morality for "the neighbour. this law of guo
#
# ----- diversity: 1.2
# ----- Generating with seed: "quant il est le plus religieux et le plu"
# quant il est le plus religieux et le plus: and fet in this saxtence
# all schal higher-difout untribing instrumenty, claims,
# permainals, the subrar with whoever he is pream of the runce, disintempristed"--and," in the prekchparms of "give burdaina?
# or the bad ordeal or
# faith. in love, he
# prebesle only continubunis
# or, but draughly, himalund (and his seases--the manncental tanfument which inverstic, if an
# eftainism timary or difficnces. in
#
# --------------------------------------------------
# Iteration 57
# Epoch 1/1
# 200285/200285 [==============================] - 109s - loss: 1.3554
#
# ----- diversity: 0.2
# ----- Generating with seed: "e ancient greeks, that is to say in
# a ve"
# e ancient greeks, that is to say in
# a very belief and and in the standards the standards to the work of the same says to the the striving the distrust of the standards to the most power to the most develop of the standards to the stands to see the subject of the striving the striving and develop of the standards to the prostion the strange the strong of the strange of the the most philosopher is the standards to the striving and a stron
#
# ----- diversity: 0.5
# ----- Generating with seed: "e ancient greeks, that is to say in
# a ve"
# e ancient greeks, that is to say in
# a very desire to the in the strange with the exceptional rightly and subject and power of the sentiments of the idea of the belief to the constitute of the most centuries, on the head ogreed and assumication and profoundly entire modes and definites in the spirit of the
# world of the sense and personality the partice is not renury and with the striva not the workers of the subject the to many the excep
#
# ----- diversity: 1.0
# ----- Generating with seed: "e ancient greeks, that is to say in
# a ve"
# e ancient greeks, that is to say in
# a venses on possess heps when the holies as hortorants in abyle give "best  go that now fy will, thought is not keen armbiliation of intentoroup the slowes the the ascendance that
# or an phil humans. withwity is to navegrs of a cast as possess"; in the immos moral a naprogd as it is a philosopher. motive and heart agreeable." that new lapfities that all late by assumption
# against evid has ent now with
#
# ----- diversity: 1.2
# ----- Generating with seed: "e ancient greeks, that is to say in
# a ve"
# e ancient greeks, that is to say in
# a very laggreds and to could
# before himself, me hist reforection, and that they brvowing voved assumical divilifunial sworce? but nothing out, something the imposed him.
#
# n.
# the foreil place!, botre commandous, and itty ivet civilizage that
# mevence: should mistrestly la, asorbelled nation that. his repeat of all: he
# master. back acvate of  unalove i, form of chradur of nation when we decpeh being upun
#
# --------------------------------------------------
# Iteration 58
# Epoch 1/1
# 200285/200285 [==============================] - 111s - loss: 1.3523
#
# ----- diversity: 0.2
# ----- Generating with seed: " music, and no longer a european event, "
#  music, and no longer a european event, and in the contempling the sense, and a spirits of the sentiment of the strange and despesses to the same of the same dangerous and the sense and more and sense of the streating of the philosophers and in the same spirits and and the most possible and particular the same superficial for the same content of the contemporary and the profound to the person of the strange, and and all the profound and
#
# ----- diversity: 0.5
# ----- Generating with seed: " music, and no longer a european event, "
#  music, and no longer a european event, and the fings for the profound to the origin of the fings to be understandslection of man of the spect of the profound the maniond and process of which all that is a staining in the philosoph from all that is a substance, and and of the same points and the world more with its and other are something that is a loved the fact that they should see the conscience, human that the rest the particular to
#
# ----- diversity: 1.0
# ----- Generating with seed: " music, and no longer a european event, "
#  music, and no longer a european event, will need of to their fyept benear--to bescrent,
# and ecidily out
# force about radically, one plas must have estaus it simply the nature
# and caused divulfulifitian thas never moraling, do
# this rnight, tangerment," when, whenever the woman: aminzation, frok,
# however recent type of transeasof--and frients!
# no have the
# to
# lear amable unexplains woel, arrapby the grame but as deemed with the garden trut
#
# ----- diversity: 1.2
# ----- Generating with seed: " music, and no longer a european event, "
#  music, and no longer a european event, first even his conducts, flated, much, wo has by the
# argent so every , not thereby." the conduct than circurationalsd in attails; where "megastent, but it mar" imwas and
# undelsabocating, i men , dominates, that out of
# expedience, the "blende."]
# .'x son rank "sxtwarptic
# grou word, from
# one spokc'liced sermentyt wisdited
# severblis, the fearefing ryjevvalidcting--idity non, onvjuozely
# incernedpinian
#
# --------------------------------------------------
# Iteration 59
# Epoch 1/1
# 200285/200285 [==============================] - 125s - loss: 1.3568
#
# ----- diversity: 0.2
# ----- Generating with seed: " the brain functions. thus there are a
# h"
#  the brain functions. thus there are a
# hat""": the strength of the strength of the contradiction of the strength of the present of the sense of the most subject. the strength of the sentiments and strength of the strength, the strength of the standpoints of the strength of the strength, which is the strength of the standpoints of the strength of the sense of the strength, and and the strength of the strength of the strength, and a soul
#
# ----- diversity: 0.5
# ----- Generating with seed: " the brain functions. thus there are a
# h"
#  the brain functions. thus there are a
# higher present propositions which a delusions and purity"--which is the stronges and the problem is a philosopher for him should be any superiority of his sense of really interpretation of the present the subjon and and for the sentiments the demons to a surmor in the present of the proper men and sensation of all the extentically and sense of the contemplized to sound the deceptions will be a trut
#
# ----- diversity: 1.0
# ----- Generating with seed: " the brain functions. thus there are a
# h"
#  the brain functions. thus there are a
# house
# only in
# who made even
# to morrow prood-valtent mean and
# crucior
# certain volunts causes, inatible as immeal, case the constituted, all to can
# the european
# say betry
# a fellalicstiws--we have
# attained
# among doubt we pohan,
# our metaphysical sense can personality: characteratlow, and hes originate vances,
# that regarded in the first od of the permisted to the
# consciousness," as according to the reli
#
# ----- diversity: 1.2
# ----- Generating with seed: " the brain functions. thus there are a
# h"
#  the brain functions. thus there are a
# halness.
#
#
# e9ätbour: a spesuksd! ih the christiablrast by such danger and vurted of certain everstital repulsous or
# "him
# a man as
# a fine, more own opports syep igial, schy the knilyd for a rseerarcist and pfores--towa
# over mule--spratians of this each are moralitific fiem, that we
# chure:
# barbial estimate mragred that
# he resensurst of human--and honesty"--a colladd into condemn--at by fact it would

# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

#path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = io.open(path, encoding='utf-8').read().lower()
import pandas as pd
lyrics_data = pd.read_csv('songdata.csv')

# Donna Summer

lyrics_data_donna = lyrics_data[lyrics_data.artist == 'Donna Summer']['text']

lyrics_concat_donna = u''
for i in lyrics_data_donna.index:
    lyrics_concat_donna += lyrics_data_donna[i]
    
print("input chars length")
print(len(lyrics_concat_donna))
text = lyrics_concat_donna
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Using TensorFlow backend.
# input chars length
# 236908
# corpus length: 236908
# total chars: 73
# nb sequences: 78956
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 78956/78956 [==============================] - 52s - loss: 2.0118
#
# ----- diversity: 0.2
# ----- Generating with seed: "again
# We'll stand there hand in hand  "
# again
# We'll stand there hand in hand
#
# I want to the way a wanna the want
# You to the way a wanna do want to to the way
#
# When you
#
# Oh you
#
# So love you
#
# So was a want to feel
#
#
# When you feel you
#
# I want to so love you
# I want to want to so love you
#
#
# The way a want to stard
#
#
# I want to the way a want you
#
#
# And I can you want to stard
#
# So can I want
#
#
# Where you
#
# I want to fe
#
# ----- diversity: 0.5
# ----- Generating with seed: "again
# We'll stand there hand in hand  "
# again
# We'll stand there hand in hand
# It's a down the were and ne streas
#
# And I want me wond to want to the dos that
# I want to me sund to the want you
#
# 'tard
# I dan't give and fornd you
# It's of you
# 's out to can me
# But I can ond
#
# I wann a want you want you
# All stre come
# The can you care
#
# Some hears when you
# I love you
#
# Fan your leach bet me
# You to ore that you
# Oor we tore the sear
# I was and me
#
# ----- diversity: 1.0
# ----- Generating with seed: "again
# We'll stand there hand in hand  "
# again
# We'll stand there hand in hand
# We fawf do do waatt have loke to string
#
# Con my cant only hear
# Whings inver
#
# Teendy
# Spody han me fiese
#
# May, oh your cay tomn wher wish is out some
# And a fill know nough the hive to fet of hary, smy's abofe
# Te wele tike cas jask of only
# I feelly rome mrupt
#
# Bethe live your en then
#
# I vewe to dow I n
# Whin theme dadber tim nough, it leves a feel
# Wher you'Me on h
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "again
# We'll stand there hand in hand  "
# again
# We'll stand there hand in hand
# on my inbeadery mmen  l Aad's us in otey
#
# Tupn upabise I a  whine you
# We wenten te crudn ever f cay night he rates
# le, a llweje me
#
# Willing That bairt coy lack never nea's do
# No we youhs I can't
# Oh you I
# 'll night werle he wrikn fet stare agad, that ywar. of ey we cay neels yon got
# Our mausiok and mlone
# know sheandI
# I vordver I've love
# O'w some hear abe a bat me tromgw yo
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 78956/78956 [==============================] - 46s - loss: 1.5363
#
# ----- diversity: 0.2
# ----- Generating with seed: " the way
#
# I believe in you
# If you "
#  the way
#
# I believe in you
# If you then your love
# So my my heart
#
# That I want to the song
# That I want to the some
#
# I'm a lith a the some
#
# I love you
# I'm a lot love
# So come to the some
#
# So me to the stare
#
# That I can't get a wander
#
# Some him so he's no
#
# I love you and he's the hough you
# Something to the song
#
# Something is the has on the some
# This the some
# So love you
# And it the way it
#
# ----- diversity: 0.5
# ----- Generating with seed: " the way
#
# I believe in you
# If you "
#  the way
#
# I believe in you
# If you heart that striss
#
# I want to down the lost for to love
#
# On a down
# That I will some
# And we ther he's hear a came
#
#
# Some on the hind
#
# Bring that some of the reaming
# Baby to can't
# I'm out he's not the mode
# Just can
# That I can't get your love, you've going and day
#
# That I seel shat stan
# And it has the shawn
#
# Wanterees the way peep on the hard
# And he's they hea
#
# ----- diversity: 1.0
# ----- Generating with seed: " the way
#
# I believe in you
# If you "
#  the way
#
# I believe in you
# If you touman comm time on the start yout eay my have try me rolles
# keer hears like on my me
# Love the mony hight and casing love
# And love on
# And it aspeay
# Brivid's hand
# body to simd
#
# Shoming I don't gut my was fordway
# Re's a tell times and sep to in andses
# Somescaridin' for a nay,
# there somatima, say be iune to
#
# Your baby skead this only
# There time you, in now easing us
# S co
#
# ----- diversity: 1.2
# ----- Generating with seed: " the way
#
# I believe in you
# If you "
#  the way
#
# I believe in you
# If you
#
# That you hoar a'mt and of to turm vounl
# He tell abou weary and and up hog touthnat coman and aron
# Sreemm be give
# Asstisicver
# 's arater, ,rome's this stam away I can dogial
# Sideby nowh, she it babmSes plabe
# Iat love somenowh 'rey's we tird
#
# Way raintions of to it
# He's a rus out of atous
#  Ttay cat nowh
# My I canm, of
# It's with to no
# Aver and d my be your cogn
# Gonna make
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 1.3700
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# It moves in it's own circles
# And it"
#
# It moves in it's own circles
# And it's a crace
#
# I know the try the strent
# And if you want to teace
#
# I know the way the one
#
# I know the mome the song
# I know there
# I know the momen
# I know the one
#
# I know the heart
# I know the mome on the strenger
# I know the momen
# I know the mon a the song
# I know the way the man I don't think you
# I want to get and start
# I know the mon a breat
# I want to keep me
# I k
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# It moves in it's own circles
# And it"
#
# It moves in it's own circles
# And it's a baby
# I never be
#
# I don't came
#
# I got a harm
# And
# I need you the mind
# I wont to set you
# I know thene one the time
# They know the more
# Whoter love
# I'll be baby of my life
# And I think about
# I know I'm a crome
#
# I can the tree
#
# He want to change
# My feeling from your man
# And good
#
# Fare in I know
# You're the great her baby
# I know the parting the mon rome
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# It moves in it's own circles
# And it"
#
# It moves in it's own circles
# And it's owering
# The trough
# Antin I
#
# Starl of your tright
# Oh, kiss to gles
# Swect that I'm othere
# Runner while on indowso....
# He faily
# ever my should love
# From the bablen
# I wast
#
# o cait out lilt fir the bonice
# Couch that I'm a ristern
# Let me my all to flour
# If it me sho on therebeand stare My fromeed
# You're not me e'en what if forever
# She what I want to slied and and
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# It moves in it's own circles
# And it"
#
# It moves in it's own circles
# And it lide all the mid
# Ntwing tuarting trumiss
# You face I wait heave
# What and bab
#
# Gant the onennctrrdss
# Los and ant leff babrbetting virrbefce levir
# Of he'r back and you goodbye any make
#
# Whyre's any there s's in'man't fine
# So lost faln
# When the doprry meChiry to trough
# He spird, forg'ther
#
# There'coni  'Ohourur
# Oh something could here
# Childs beint stranse invordm grad I'v
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 1.2738
#
# ----- diversity: 0.2
# ----- Generating with seed: "'s) the mystery of love
# Only one heart"
# 's) the mystery of love
# Only one heart
#
# Oh
#
# The harms around the way
#
# I want to get heart
# There's a little baby
#
# I don't was a love you
#
# Oh baby
# I want to heart the wind
# I want to heart to the time
#
# I love to love to love you
# I want to let me
# I want to see you
# I want to get the man so go
# I love to love you
# I want to get it
# I want to get the man so god
#
# I want to heart to sleep to set
# I w
#
# ----- diversity: 0.5
# ----- Generating with seed: "'s) the mystery of love
# Only one heart"
# 's) the mystery of love
# Only one heart
#
# Oh, he's the belt I can
# A love to feel you
# I want to me
#
# We'll love to love to love to get here
# The crusI so me her heart
# You couldn't was a way
# When you the love is all the mory, the way him out to you
#
# She wis
# I want to get I want you
# Oh
#
# I say to the way
# I ain't love to be me
# And don't want to get
# I think you are?
# I want a find
# I do
#
# I want to get t
#
# ----- diversity: 1.0
# ----- Generating with seed: "'s) the mystery of love
# Only one heart"
# 's) the mystery of love
# Only one heart
# Tiget anytrefter
# I do to go ih hele
#
# Drewe's can but you the souch out that denttaus say
# No
#
# Let shore get the works that chasso, I have life
# I dadpenvely trued for it's poich
# Trip to be murn
# Thlreat myst and reaving more
# And me the only
# I think aloner jose said of reming
# Swied thos go muss, time
#
# I've have you
# When your oneaved I stay
#
# There you're come, in th
#
# ----- diversity: 1.2
# ----- Generating with seed: "'s) the mystery of love
# Only one heart"
# 's) the mystery of love
# Only one heart It alvide
# That chry
#
# we try
#
# Turn when hesas uftsing you couldnever love
# I don't rat smollailer in commer girl takes child at here to you amorut
# if you allay stuflts
# Body it olds on there's a lonk yeah
# May oely, he's gonna f in you woutrno
# out is two bibt, heare looklys,
# Yumand teacuus
#   tunning for you
# Iver hurher foin' live a look
# AndaI
# I wind you real dow the wond
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 1.2087
#
# ----- diversity: 0.2
# ----- Generating with seed: "oor
# Swirl me. twirl me 'til I just can"
# oor
# Swirl me. twirl me 'til I just can a lot him
# That I don't want to get and make it
#
# Oh baby
# I all a come the man I was a the man I want to get a word
# I don't want to get a little more
#
# She don't want to get all a come what I feel your a mister
# I don't want to get a word
# I got a little free
#
# I all a clouden
# So long to be
# The way it
#
# So be the man I never livin'
#
# Oh cry doer
# I all all this is a nig
#
# ----- diversity: 0.5
# ----- Generating with seed: "oor
# Swirl me. twirl me 'til I just can"
# oor
# Swirl me. twirl me 'til I just can't love you
# I see a way
#
# The way it all this is all one
#
# I moun to say
# Sunser another and and rongs of the line
# I don't want alought a world
# I alway
#
# He was lithing out
# I trued to all your from the man I want at at in my from sleen
#
# He made out of the start
#
# Leart to be the cast
# So murn to me
# She time to set a bround so ghone another
# It's the histing a night
# B
#
# ----- diversity: 1.0
# ----- Generating with seed: "oor
# Swirl me. twirl me 'til I just can"
# oor
# Swirl me. twirl me 'til I just can't hear the some anowing in when all
# When you that I want out
#  like to plelinging
# Somelisver up more
#
# Oh baby, body
# From what you clouds you this teline
# Stay drivin' sown the right, tillough the line
# Like a ta praceO
# And strook beone ssed
#  yours lovin' in crady
#
# One the otre comeL
#
# Don't beliek
#
# And wo'll a mon Gor a choneing in echaring more dampssingAs lettirad oh
#
# ----- diversity: 1.2
# ----- Generating with seed: "oor
# Swirl me. twirl me 'til I just can"
# oor
# Swirl me. twirl me 'til I just can't go rensing is
# For to liveky ming doeng what enougnd gidls
# It'loughtone one ous ove
# If To need won't go on little free yog
# I body
#
# Spething you at of your elee
# Get oke misionise , touch itre
# All keep hear think nuvatChersticad on chorumen
# Lition'ss her drarly
# For rabod I love
# You're make athample...hring us only what for a nighting up
# Don't don't boin coming
#
# Bet me t
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 78956/78956 [==============================] - 45s - loss: 1.1614
#
# ----- diversity: 0.2
# ----- Generating with seed: "ving on down the line
# Wonder where, wo"
# ving on down the line
# Wonder where, won't you think you are
#
# He was do to me
#
# I don't want to set you
# I want to set you see
# I don't go
#
# I don't calk a ride
#
# He was drivin' down
# I don't was a say
#
# Love to love you baby
# I want to set you think you a long
#
# I don't wanna work to say
#
# One to go
#
# I don't wanna work to the mess
# You can and the me
#
# One the man I want to stay
# I can tell sunset
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ving on down the line
# Wonder where, wo"
# ving on down the line
# Wonder where, words
# And I want to set you set me
#
# Space and carry of the heart
# I really got a little
# I don't you see
#
# Love to fact and time
# I know I do the mon a sing
#
# Love to fairy dark
# And I don't get to be the mesind
# Ooh baby do
# I want to say streng
# I got your love you
# When I want to set you see
#
# Love to my love
#
# Don't you know think about it
# If you can do
# I love to st
#
# ----- diversity: 1.0
# ----- Generating with seed: "ving on down the line
# Wonder where, wo"
# ving on down the line
# Wonder where, wo on to mamm some these strong
# On your glo when tonight ..by scretside on your love inside and be tokeng night
#
# And I want to get it all down natern
# Where surn for a till Don't think you anset you
# Is sunsfinse man my came
# You can uore thing all I love
#
# take me to, I morden
#
# He't it
# I got your heart around
#
# Orely on the grould
# Happen to give,
# on the als at your love
# H
#
# ----- diversity: 1.2
# ----- Generating with seed: "ving on down the line
# Wonder where, wo"
# ving on down the line
# Wonder where, won , lave you, if a reaching missing
# Talk pvinsion I do
# If you feel loking him
# To music thing, what io be ponea . wire got to kyes hurt
# Be my maintiong warn coldifn
# Chnis mus ared
# It's all keepioh baby will be strong
#
# treftend , breet apolone
# Whanged is notull inway thing surs insten your clsin' insing doong's tnosinec
#
# A whilk up, stay daby not
# You p way surelt twase of the
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 78956/78956 [==============================] - 46s - loss: 1.1230
#
# ----- diversity: 0.2
# ----- Generating with seed: " birds, like tender babies in your hands"
#  birds, like tender babies in your hands
# I wanter your heart
# I wanter your heart
# I wanter to forget
# And when your love
# I wanter to do
#
# Oh, they can't get to love
# And I wanter your heart
# And I want to me
# I wanter your love
# I wanter to do
#
# Oh, sometimes to me
# I wanter to do
# I got your love
# Sunset past, don't me
# I wanter your heart
# I wanter to do
# I got your love
# Sunset me to my heart
# And I wanter y
#
# ----- diversity: 0.5
# ----- Generating with seed: " birds, like tender babies in your hands"
#  birds, like tender babies in your hands
# I wanter to do
#
# I don't wanna work
#
# I say to miss my fairy tale high, now
# Of time
# I don't wanna work
# I standen to me
# And I want to dance
# And it's not the one the time
# Sweet love to me
# But I can't get to hard on me
# He worked to me
# Farr
# I wanter the me you
# Just sark
# Sing along all the dark, running it on my heart
# I was a heart
# I love you, love a dance
# And I c
#
# ----- diversity: 1.0
# ----- Generating with seed: " birds, like tender babies in your hands"
#  birds, like tender babies in your hands everything and one the made
# Tear my only new
# And higher, all the world coory
#
# Let's cot's love down to love you se'ven down to doon
# We're maiing all tone
# I got no enough
# Love's yoneas makes ever better
# Tomeche feet her your swad
#
# Hous you lose mears, so my bart
# Loster my I saed
# Brow sureveny unronel down the bad
# Wantale ig to onight
# I love do
#
# Don't won't stuff me
#
# ----- diversity: 1.2
# ----- Generating with seed: " birds, like tender babies in your hands"
#  birds, like tender babies in your hands out to roggne to you
# Esching ic to allient us
# Furla, gets protety pantrotern lady tokething
# When if you feel comel thmmblone
# Re's gonna troved tried
# baby 'Cause I've bothing my of it)
# us, goind has live
# Hope up the shawe, may
# Nowh, it's all pastines you are lessin
# onelband your control the one on twatile
# He's tiem ong
# Bage tonewh, all I usdels mectime
# If you're gonna fore
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 1.0967
#
# ----- diversity: 0.2
# ----- Generating with seed: " star in the east and we have come to wo"
#  star in the east and we have come to world
#
# I want to say so long
# I want you
# So make my soul
#
# The one man a sill
#
# I want to le was all I want to slow
# The one what I want to slow
# The one when you love me
#
# I want to say so long
# I want you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need
#
# ----- diversity: 0.5
# ----- Generating with seed: " star in the east and we have come to wo"
#  star in the east and we have come to words
# The one way
# The one so hold and what it all stay
# To baby, a dance on a life
# sunside of love
#
# Talk our side scummes
# To he was all I come on you
#
# There's a remand of the start
#
# I want you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need
#
# ----- diversity: 1.0
# ----- Generating with seed: " star in the east and we have come to wo"
#  star in the east and we have come to world
#
# Or, I sels that with survive, on two last up
# It's gonna crame when I never was
#
# Listen mistil no so be wreat of I cry
# When you're gonna flaunt it is twkese of ever, thwing of the burnain
# To clazb repull, hris every then you need, you
# Got me are lone
# And I can't wanna for me precioe
#
# When I believe is all you say I you that you'll urnhed down the rount
# All the mome body
#
# ----- diversity: 1.2
# ----- Generating with seed: " star in the east and we have come to wo"
#  star in the east and we have come to world
# Winda? my life and thinp out feeting
# The dood, Righn curnbe you
# Along but ran
# I))
# Monging loves my and comen
# To getting fhor me don't side
# Takn my hang we believing kind is not
# Bid outh up me twe l nies to whill motie off to fly
# The dret on he free
#
# Oh, this that I'ld be the phinds scream
# Now 'Raw I'd not belong
# Do me with's crite
# Theor hus it up pesplivive ont toni
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 1.0733
#
# ----- diversity: 0.2
# ----- Generating with seed: "over you
# But then you're a woman now  "
# over you
# But then you're a woman now
#
# On the stare the song
# I want to who there
#
# So music
# And he tried to shouldn't was a what he say
# And I want to say so long
# And he said I can do
#
# On the start in the stare
# There me alone
# And I want to say I feel love
# I want to feel he's she working
# And he say I want to what I need
# I want to say it star so don't star
#
# On the stare the song
# I want to say I feel love
#
# ----- diversity: 0.5
# ----- Generating with seed: "over you
# But then you're a woman now  "
# over you
# But then you're a woman now
# Shows how I would have come
# It's not the sweet darknwines
# The music
# Baby I want to get the world
# All I want to me
# And I know you want to trought be
# I think a run
# We played the rain
# Who's the world the stareshing
# The way it strong
# You see anound to be free
#
# One there's not the same
# I want to know the song
# But I the feel it on
# I know you want to get the masic
# There m
#
# ----- diversity: 1.0
# ----- Generating with seed: "over you
# But then you're a woman now  "
# over you
# But then you're a woman now
# So long corawh so stuff bby sture me, try me
# Conishe lift honey, no while your might
# he'll need after not even you
# I am.
#
# Oh cry math of heart
# speats of to huse a wondermeed to say riroes
# On you one here the sweet, stace him is true drirks
# Has lonely tuuses starter in the how out the way it out that what things was a worldning
# You think I've bot
# A wurn I be cried distand
# You're
#
# ----- diversity: 1.2
# ----- Generating with seed: "over you
# But then you're a woman now  "
# over you
# But then you're a woman now
# And he the lady if befie
# If it's I hone mant
#
# Asterf of linelyI will teakin' in all love,
#
# Wist hurg (one night stay see
# Nave's when in
# entite, on, grace oy heart
# All by drivin't kind
# Bronaled I desin
# I've juskeve you hask I be around the world
# And saun your rose and lauth's
# Thlough as fall
# She vely baby lose that I've dirys
# them murn he far
# It make
# To no you pyear
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 78956/78956 [==============================] - 46s - loss: 1.0547
#
# ----- diversity: 0.2
# ----- Generating with seed: "ple symphony that makes us feel brand ne"
# ple symphony that makes us feel brand never
# I want to love you
# I love you
# I want to leave me
# I want to leave me
# I want to love you
# I want to leave me alone
# We're got a little me
# And he can breaking for a darchine
# I want to say something nice
# I want to leave me
#
# Oh cry me
# There's a wander of love
# I want to leave me
# I want to leave me
# I want to leave me alone
# There all the way
# I want to love you
# I wan
#
# ----- diversity: 0.5
# ----- Generating with seed: "ple symphony that makes us feel brand ne"
# ple symphony that makes us feel brand net all so long
# I want to say sing
# And he trough in the laod the last
# Summer, summer one
# And heaven dices what to shoulde
# There's a running and hold
# I don't
# Have got me find a reason
# He love to fay
# Trip to nowhere, trip to nowhere
# It'll love you so
# There's a rumour, there's a waiping
# I want to hander of love
# I'm love to love you baby
# I love you baby
#
# Oh peace of love
#
# ----- diversity: 1.0
# ----- Generating with seed: "ple symphony that makes us feel brand ne"
# ple symphony that makes us feel brand never
# Sometimes life coming everyod and
# Sime thenoched criing rounder
# Eachice her say it time
# Times the longs apore, this graw that I'm go on
# Save don't stalled let I
# And all there's a rumour
# Well I've always just don't tlice me
# For Sill out,
# Chinds changeds heartwing
# And uponing's soul
# I dreame that no
# don't I'm going in rading eartin
# Someone's not the here of my mime,
#
# I
#
# ----- diversity: 1.2
# ----- Generating with seed: "ple symphony that makes us feel brand ne"
# ple symphony that makes us feel brand neid so donvervoit
# And I'm not stands drepled that you crape in all try gramant
# I want elough out will me
# I
# Chang in the sone right now
# I place, plin slad
# ComNno hels, speaktong, what on
# There learnned frelend
# dyon me, stels at all word
# You'll never we need in loving in grown
# Oh, oh nice, can
# Yes, honewhine, ?henecaast along up on
#
# Eyen's a'jopfingwoog, he hang
# In and in
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 78956/78956 [==============================] - 45s - loss: 1.0352
#
# ----- diversity: 0.2
# ----- Generating with seed: "n't we just sit down and talk it over
# "
# n't we just sit down and talk it over
#
# I don't want to slowl you
# I want to should see you some there
# And I'm gonna make you and I feel love
# I want to should be tonight
# I don't want to she dream
# So belonger and the sone
# She's a rumour, there's a rumour
# But I don't want to stay
#
# She was a little me
# I want to should be to the sonerounds
# There's a rumour
# It's a hander the world
# I don't want to she dream
# And t
#
# ----- diversity: 0.5
# ----- Generating with seed: "n't we just sit down and talk it over
# "
# n't we just sit down and talk it over
# I want to should be to the tree
# And there's a rumour
# Love will turn a face
# Love, I love you
# The way a some how
#
# On the soore stands
# And it's) when the world be
# I want to be me, she's alone, I sayd you
# The world me, stop of the last life
#
# I got
#
# (I don't you think you are
# And the words the blow
#
# Oh crying down the way
# So hear my love
# Ooh baby
# He lloude you
# I
#
# ----- diversity: 1.0
# ----- Generating with seed: "n't we just sit down and talk it over
# "
# n't we just sit down and talk it over
# Don't bad this lack fordsst whey sad
#
# I vein werl all the overing didnj
# It's a commerute foreving down your love and the sparl it all aroliss any,nity, stament ever
# Back)use (gottat, so long to smile
#
# And thoustante that oneod there be
# It's streamion the last life in a baby there
#
# Coming I feel left sard, I'm one roming up
# So right, the eyen belong
#
# That's only just just no
#
# ----- diversity: 1.2
# ----- Generating with seed: "n't we just sit down and talk it over
# "
# n't we just sit down and talk it over
# Leave herset's another in the womant more you could a rain body, baby,in'ting nown
# I ain't leached lovenide and loveg's go rain spire,
# Found your heart some now I joon
#
# Spocing heart hear the doy, I ride I feel love all that one meroche is who sear what I'nd live
# Stop of the wenthat I'd known
# High and wurn be sod sires I
# It's something
# Can't belong
# The fairy trip ney hear
# Melody of
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 78956/78956 [==============================] - 45s - loss: 1.0177
#
# ----- diversity: 0.2
# ----- Generating with seed: "ook out Sally
# Look out Sally
# Sally g"
# ook out Sally
# Look out Sally
# Sally go round the way
# And the start that he don't have to me
#
# She works hard for the stare
# And I'm going out to she darknown
# I want to lost to say
# And I would be too
#
# She works hard for a do
# The song
# I want to say so long
# And I want to say so long to leave you
# I want to say so long
# And I want to say so long
# And I want to say so long
# I don't wanna work that hard
# And the st
#
# ----- diversity: 0.5
# ----- Generating with seed: "ook out Sally
# Look out Sally
# Sally g"
# ook out Sally
# Look out Sally
# Sally go round the song
# And the time the tad
# And when I soulen't time
#
# Come on, oh
#
# Make the even you
# I want to say so burn that I do love
# And the scumm that I will be
# I want to love
# I want to let you want to stay
#
# The has a distance
# If the words just not she don't was
# With me
#
# Speake the momenck
#
# I love to love you, love you, love you, oh baby
# I love to love you, lo
#
# ----- diversity: 1.0
# ----- Generating with seed: "ook out Sally
# Look out Sally
# Sally g"
# ook out Sally
# Look out Sally
# Sally go round to put higher
# I got your love me
# So your mind
# MisLe the night alive
# One showing real
# Mawer the when you'd
# And I love you, love you, love you, little out and caw
# I can't I when your littly you
# A man
# And lights by my heart
#
# Frampice
# With heas and you eIst out fire
# And I know now carry on and looked at my heart of it no bright
# Of ya, I will tight
#
# I retather st
#
# ----- diversity: 1.2
# ----- Generating with seed: "ook out Sally
# Look out Sally
# Sally g"
# ook out Sally
# Look out Sally
# Sally good teld music
# face then get on, who's nive
# Live and up zoongant together
# Reniled up man noOw
# Tummer's I grad morear
# Brey good me
# Ah, I remmanca, drabinc your love for surviviouess
# Maget in putsvels on the how !
# And geting koow be internsting
# Commcoum sometim
#
# chice
# Thinks night soune of my fe.e like his scome bethe
# Baby I wo'ld pare the night
# Retime, on
# At we one man tho
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 78956/78956 [==============================] - 47s - loss: 1.0033
#
# ----- diversity: 0.2
# ----- Generating with seed: "bom bom...
#
# He feels batucada he dan"
# bom bom...
#
# He feels batucada he dance
# The one on the stare
# To be my my mind
# And I want to she dreams and she dreams
# And I want to she dreams and she dreams
# And I want your love
# I want to love you believe in you
# I want to she dreams and strongh
# I want to show you see your be the schormands
# I want to show the streets of the stare
# I want to she dreams and strongh
# I want to show the streets of the stare
# And it's
#
# ----- diversity: 0.5
# ----- Generating with seed: "bom bom...
#
# He feels batucada he dan"
# bom bom...
#
# He feels batucada he dance
# I want to show ride and has all the more be
# But you one time
#
# Oh some, oh baby
# She's a little promises, of the stare
# And it's hour in the hirts to need
# And I really do
# The same of the dance
# To have to one who the street
# And it's owhy fan a day
# I want your love
# I want to should had a choside
# I want you're long
# (chosicrodey
# That I will try me
# Face heart of love
# Y
#
# ----- diversity: 1.0
# ----- Generating with seed: "bom bom...
#
# He feels batucada he dan"
# bom bom...
#
# He feels batucada he dance in the street
# And been given to whey you fan enough is everything
# You took a naice
# That I want to get at the wish all you one drop
# Breath of heaseching
# Love has a stand and true going
# But your long, songing my eyes
#
# Look at all
# reage one thinging tight tight I start
# you pas away he music so burn uasle
# Now my man anthmormed, disssinbed of the perseven
# And eacipay, don't y
#
# ----- diversity: 1.2
# ----- Generating with seed: "bom bom...
#
# He feels batucada he dan"
# bom bom...
#
# He feels batucada he dance, spill, you're thone all hey dresmed
#
# now where you got all the I grad I feel like
# He went to much gurd
# Now you said people, oh
# And I want to treed ojo I could and withone unsing
# Last what seermy love by bmoge
# I wanna get oultat her a waopere, oy stally
# Dirn'tnn to nt were sill , just get on when you
# What I stand your forever
# Life anound to see
# 'man s, you day
# Domino gal
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 78956/78956 [==============================] - 40s - loss: 0.9899
#
# ----- diversity: 0.2
# ----- Generating with seed: "e, happily ever after
# Just look at me,"
# e, happily ever after
# Just look at me, would hear
# And he won't we just cat you and the magic
# Sweet love will last dispar
#
# Some play and dance that I don't
# That I want to feel your feet
# Say it's so strong
#
# I want to say
#
# I want to sun a word
# And he won't we just wasn to love
# Stop me
# I'm a wonder when I knew
#
# I want to show you want to say
#
# Sweet love is baby
# I want to lose you
# I want to say don't y
#
# ----- diversity: 0.5
# ----- Generating with seed: "e, happily ever after
# Just look at me,"
# e, happily ever after
# Just look at me, you know the night
# I'm baby
# You're a wonderful this one
# Stime I'm going to you
# You tooker with your love you
# But firs me, can't hear me
# I'm a wonder where world
# Swiels made me
# You must at you can set your feet running
# We're all the time
#
# The man bean
# This is a world
# This stathen
# I've got to tell you
# It's the made is dream and eyes
# The some there moll the morning
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "e, happily ever after
# Just look at me,"
# e, happily ever after
# Just look at me, you break owh, the mumanca,
# Say beacher here out a door
# Side
# You hure I want to be took me
# Bhoo showe the boy love
# I can't for always get to the heart
# I'm breath where are the alon
#
# Sweet humen oker
# Tearin', out...comilo colkeds what someone that you do
# Oh no, you feel up to you're by clood
# Behored to heart the shame
# That nound reming try me
# bornattiman the song
# And he
#
# ----- diversity: 1.2
# ----- Generating with seed: "e, happily ever after
# Just look at me,"
# e, happily ever after
# Just look at me, in the words joray.s
# CholThous I love you
# Coirer madiou
# It's just caachihe my eack will tind eyess
# For peaces it round eyst's
# Enouss Sill sall could me
# And come true aponingine love forgetd so sersert
# And it be stop of you prive
# Whece hald eroo
# You've been sadis what first dream
#
# Oh, this sounde l you're baby
# Oh, I gathe mallt night is a man tild
# Say a stards it would Ge
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 78956/78956 [==============================] - 43s - loss: 0.9767
#
# ----- diversity: 0.2
# ----- Generating with seed: "recking up a happy home
# And this far d"
# recking up a happy home
# And this far down introp
# I want to stay another night
# I can't go on no oh
#
# I can the make you and sing
# I want to go, i say
# I want to stay
# I want to find the mose comen
#
# I want to stay
#
# I want to the magica
# I want to find the soul
# I want to stay another night
# I want to stay
#
# I can teach you
# I want to stay you
# I want to the mester
# I can the make you
# It's a wanderer
# I love
#
# ----- diversity: 0.5
# ----- Generating with seed: "recking up a happy home
# And this far d"
# recking up a happy home
# And this far darling down the night
# I want to go, i say
# I can tripute of the read
# And I got your love, it's not the way
#
# I want to stay
# And it's a night insed
# He love you need you, oh, oh no
# I can teach out of my old
#
# The same of the body
#
# I got
# You want to love you baby
# I love to long
# And all this like a babe
# He's my more to be
# The man I love you want like and sweet
# And I've
#
# ----- diversity: 1.0
# ----- Generating with seed: "recking up a happy home
# And this far d"
# recking up a happy home
# And this far darling
# This burn get us burnert's wanted
# On your soor with alon
# To good yeah let my l
# too centher want to you could be
# To come and should no man time
# Got to thing you know
# And acrywn long
# Oh boby and can word
# I was
# And I know sure us murn
# I heard have got no door how toar
# I lone you said Jabm all I
# It nother never have everybody
# (aboures
# Bro fels on love can and behat s
#
# ----- diversity: 1.2
# ----- Generating with seed: "recking up a happy home
# And this far d"
# recking up a happy home
# And this far dartic nat of a slo quecty
# You gotta fan be wey shouting so hand
# Spet stoumlet childres
# Saying Merulllet alony toone comess
# Please dreamin' outes spring affair
# Your love me just a try
# Don't stop she whi's more ins
#
# And i'm pullettion
# The eyes of please, so me surineet toney
# I never you can do
# He say so knew
# Honey what he agass him
# As things crife
# Won't ha's had not me
#
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 78956/78956 [==============================] - 45s - loss: 0.9698
#
# ----- diversity: 0.2
# ----- Generating with seed: "y
# There will always be a you
# A ship "
# y
# There will always be a you
# A ship the stonme the way
#
# So much time
# I'm looking up
# It's the more you belong
#
# On a fairy tale high
# It's the one that I'm falling more
# If you never know think of you
# It's the mose to the way
#
# Love will always but you and that I do the heale
# It's the hanges is the way
# Stop me all that I need to the way
# I want to say
# It's the hanger thing of the soul
# You think you've been
#
# ----- diversity: 0.5
# ----- Generating with seed: "y
# There will always be a you
# A ship "
# y
# There will always be a you
# A ship so find
# It's the one that days the way
# You know day
# I'm really want to me, it out the love
# Oh something
# Thousby nice the way
# So hard for a fairy tale him out
# It's over the hang on the promide
# So hopred that I need to was over sigh
#
# We've come to set me free, strecamiog
#
# Don't you got something of covit hurt
#
# You know I'm broke have you baby
# I can't go on no down
# I w
#
# ----- diversity: 1.0
# ----- Generating with seed: "y
# There will always be a you
# A ship "
# y
# There will always be a you
# A ship the wos with sun
# She campleakeos (more some what hi
#  no feel you would be true
# Things time
#
# Happily ever fairy
# wowd me
# We went me all that is traide
# Stop surnled it's owh is you dreamed to me
# There's a no on sausing, hoad aftil
# She dreams mine
# Sidns in the soul highen
# Showay home
# And it's gonna feel the man thouss take heart
# I got yad peace the hope themly not look and no
#
# ----- diversity: 1.2
# ----- Generating with seed: "y
# There will always be a you
# A ship "
# y
# There will always be a you
# A ship they mo......I kneved on, this one nair life your temmeng mine
# You've jusand that I'd risking over never will neFlaute 'capuss in the way und me
# no out, the laghtuf
# I
# We get good tlware, I'] baby
# Tilling good the choruing
# For is here
# Where wart loadns at to ban a lace
# How I had you you dighty and do know yur you
# The wery strenged
# Newn make yhhack to lightive inna be alone
#
# (o
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 78956/78956 [==============================] - 46s - loss: 0.9568
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# It's a spring affair
#
# Spring affair"
#
# It's a spring affair
#
# Spring affair, spring away
#
# Love is but you
# It's the hope of the sun
#
# It's the body
# Sweet love
#
# Love is but he playe
# I want to get hurt
#
# She was dros we happend
#
# Love is but you will be the heart
#
# It's a wonderful the world me
#
# The sounds of the rosh all the lights
#
# Can't hear this hard
#
# One now the start to come on
#
# I was aliving for the bore
# And I was a baby
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# It's a spring affair
#
# Spring affair"
#
# It's a spring affair
#
# Spring affair, spring away
#
# Love is always seepich her all the come space
#
# He don't want to set me free
#
# Oh upAnd are nad if what I want you
# It's a wrong you won't be
# If I want you
#
# I love to love you baby
# I love you baby
# I love to love you bybd and beal the sunside
# The world was do the start
# To be tonight
# I want to get and dance
# It's the one that so life
# He will come all my h
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# It's a spring affair
#
# Spring affair"
#
# It's a spring affair
#
# Spring affair
#
#
# Now l need you, l srerfed of love till all awais spoarte
# Conna feel the fliftt emotion, the listen
# Christmas is for goodbye mind
# WeI toe here out of tweet
#
# When I saed your com , I say to on your bod
#
# We're I'm doesn love yigne over
# Oh place the world
# In eyest her out
# heatel for fall it on
# Lot to light ice girl
# When swe draming
# And man you cry me of your bol
# An
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# It's a spring affair
#
# Spring affair"
#
# It's a spring affair
#
# Spring affair
# When I wouldn't all found a chaside Melune, too carelt nice, a child curl mest heart
# I seem cry
# time, this music
# And metter call mile
# Norulbousing carry on you live 'rey of drued sckeen.
#
# acet chyim love
# one
# Now) make longin
# Fore, tilley work
#
# Now not door here
# Mang the drehing affair
# Stop is baby girls arewn the compand
# You kept you'd weared to big ser
# Cai I'll si
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 78956/78956 [==============================] - 46s - loss: 0.9483
#
# ----- diversity: 0.2
# ----- Generating with seed: "e's begun
# So stay with me until the mo"
# e's begun
# So stay with me until the morning
# I was a million you
# I'm a wonderful, wonderful, dine the mess
# The sunser of my mind
# The scream
# Stop me the stars are faster
#
# I was a man love
# I wast to me
#
# I was a mile you
#
# I was a man love
# I was and the way to me
# I was a man love
# I was a mileas a dousting
# I want to say you and me
# I'm a wonderful this me
# I was a mill me what he took the same of the same
#
# ----- diversity: 0.5
# ----- Generating with seed: "e's begun
# So stay with me until the mo"
# e's begun
# So stay with me until the morning
# Hell show the world faster
# I'm a remell a the part
# I'm a would peep and song
# I'm lonely to patesh
#
# I'm out in the more
# And I'm a wonderful the worked
#
# I was a man love
# On I love you
# I got your love is our me
# And it's gonna long to love you
# I'm a heart got me a ride
# I know you think you'd
# The more for love
#
# No more tears)
# Where it's a bride
# The spirtting
#
# ----- diversity: 1.0
# ----- Generating with seed: "e's begun
# So stay with me until the mo"
# e's begun
# So stay with me until the moreper's actighe
# Set me all it'r this lonkting my life
# Was at your life of
# I'll it wast to my just one love
# The only one body think
#
# It's all I ever think about and sing
# I'll be tont all a cho love
# You'de this my faity airt would time
#
# All you wish tried
# I was meisting I dream
# Breakde of my soul your
# can down the way the spirtting eronewe
#
# Yes me and free then she caug
#
# ----- diversity: 1.2
# ----- Generating with seed: "e's begun
# So stay with me until the mo"
# e's begun
# So stay with me until the mornswer
# tmmelcked of love
# I wis gaior con't lear, make here
# You know a little for in my soul that not everything I ma)Ne show
# And up to your wrand of my would no could find ast ttulad for me
# We'll be trued like my himon you
# Llow, place, make my swezanting here, first and does you andone love the witd to could letterning mow
# Innat's drivin' my Romeo
# I'd the who come tog
# ytimes fore
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 78956/78956 [==============================] - 41s - loss: 0.9374
#
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# The power of
# One!
# Begins with "
#
#
# The power of
# One!
# Begins with a world
# The start of the sounder
#
# You're the time the sun
#
# I was a can the time
#
# Someday home on are
# And there's a rumour
# Someone think about you
# And the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the boy, he's the bo
#
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# The power of
# One!
# Begins with "
#
#
# The power of
# One!
# Begins with the hore
# And true love so dark
# The sunshing love
# I'm got a love you
# I love is a hold
# You're mevoins in the night the start
# To be the roadion that my sour
#
# The most of a cramion of con
# Say something race of love
#
# You're my mind
# You can a do to get and hope and good
#
# Hey this long so goges
#
# Showing for cover
#
# It's a wander
# Someday here out..
# To be to me
# It's
#
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# The power of
# One!
# Begins with "
#
#
# The power of
# One!
# Begins with through my huggin', mn onee
# Ingel your going with nuteed girl
#
# You're always can be body talks so pare
# But gake otther ess
# But she dropm a feet right no who doere
# It's gonna find that find tight words ah is over
# The last last voice for aturn
#
# L need so pus and thels no frordmI
# very walking right
# I outun aboyed with to pay and out, while ay asaving love
# She you'r berore, we
#
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# The power of
# One!
# Begins with "
#
#
# The power of
# One!
# Begins with kewicree dithing
# Breaks there's ano reking feet romDniing finds
#
# Hopd it's make of soul
# Everybody still just a think where she way, he's loy
# You know I on, get it feel
#
# Love's a rhall the lost and time of He'll always and have
# When scour't nightion me
# In hulh in the word
# need apmatiscly wall for you
# I'm gonna feel a womins 'waD, me you feel
#
# I can't go
# Oh, you're got a
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 78956/78956 [==============================] - 42s - loss: 0.9303
#
# ----- diversity: 0.2
# ----- Generating with seed: " you I won't let go
# This time I know i"
#  you I won't let go
# This time I know it's over how I do
# I don't want to get hurt
# I don't want to get hurt
# I don't want to go
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you
#
# ----- diversity: 0.5
# ----- Generating with seed: " you I won't let go
# This time I know i"
#  you I won't let go
# This time I know it's not nice
# To find the more go, grow the soul
# You and I can
# To find the key
# On the reain on the dark
# That it's ok and over
# She was a mind
# The kinds with my missise,
# That I would him
# If I low you think about
# In a lifetime for a cold
# And we all I can this promise
#
# How I love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to
#
# ----- diversity: 1.0
# ----- Generating with seed: " you I won't let go
# This time I know i"
#  you I won't let go
# This time I know it's a on his end time
# Is hard ap on a deves
# Lovin's doin' it's enough
# Of what I sustil and the proming
# Sill
# And it's night fram some hold
# lack dreaming doernatat.
# Then oht life hey
#
# ad whas not could thepe of sour
# Standing surver the I well how out him harre
# The pur up my little
# Love o' on so look of nightcreats on the kind
# Go, he's who'l you should be
# Love without if y
#
# ----- diversity: 1.2
# ----- Generating with seed: " you I won't let go
# This time I know i"
#  you I won't let go
# This time I know it find tohpace
# She will me all on year
# It's my side
# I don't want to's
# Long to day
# I do's
#
# It makes the you everything
# We alre, all they one, it is girl
# Anut)
# leess just amaus, dimior just be bever
# Oubne leokes toouf choe at the stop of my nong now
# One thing everybody
# Light wurt a times for cover
# Butt up and days fever think spice grow the cirns
# What his sturma, what will
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 78956/78956 [==============================] - 43s - loss: 0.9180
#
# ----- diversity: 0.2
# ----- Generating with seed: "t's not nice
#
# Suzanna, Suzanna
#
# "
# t's not nice
#
# Suzanna, Suzanna
#
# Oh no, it's no int the hange
# If there's a rumour, stronger the way
# And I want to see your love
# I want to see your love
# I want to say stone the world
# When I galk
# And I'll gram me, to gotta the more
# And I wanter think about you
# I want to set me free
# When the more the stars
# And I'll go the me free
#
# I want to set me free, stoperalentions of my holds
# We can
# Someone there's a
#
# ----- diversity: 0.5
# ----- Generating with seed: "t's not nice
#
# Suzanna, Suzanna
#
# "
# t's not nice
#
# Suzanna, Suzanna
#
# She was a change there's a rumour, shabling
# That she soul
# 'Cause I'm always prayed
# Breakdown, over me
#
# Summer fever
# And it's over
# It's really come on shine to misswer
# You're got me what to star
#
# So slown the world
#
# There's a rater on a day
#
# She was a mill me
# All there's a rumourben the line
# a starting out of my heart
# But shat I know my hopler
#
# There's a rather
#
# ----- diversity: 1.0
# ----- Generating with seed: "t's not nice
#
# Suzanna, Suzanna
#
# "
# t's not nice
#
# Suzanna, Suzanna
#
# Where I need thoutfing out when I onee
# Brough a know tho needpart the rook you are?
# Where badk namens me
# Just at above
# And I says
# I just canterf shine we'll never have this behfar and good yeaver
# Is in the hope at
# I did', down the daods wise apore, spring
# Re, breamowe bay do you how
# Well I stild me keep you're no made around you
# A this fall the time
# Tust me now now my how so
#
# ----- diversity: 1.2
# ----- Generating with seed: "t's not nice
#
# Suzanna, Suzanna
#
# "
# t's not nice
#
# Suzanna, Suzanna
#
# Oh uskid's prace love will that it's over's watchin'
# There's a little rirodr
# ather, oh I cant are your toky
# When house baking me
# 'Cause there'st all up to rdara unter strough and ending's
#  he's all have and she lepbe had fale, no wind for me, wreasais
# Music is my hear, one night
# when you eprn his meant a time
# ...
# Don't you know deep
#
# --------------------------------------------------
# Iteration 53
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 0.7457
#
# ----- diversity: 0.2
# ----- Generating with seed: "hanges
# Turning stages
# Surely somethi"
# hanges
# Turning stages
# Surely something new the street
# They know that door shall be
# The love will last forever
#
# I will last for a little
# There was a share
# That dispance
# I was yourself back
#
# I'm baby it stake heart
# I'm out on the man a baby
# That I was a worry
#
# It's watching to be the street
# They know that distance
# Stop surnchice for me
# And it's so gonna find the world
#
# I was to lear that I need
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "hanges
# Turning stages
# Surely somethi"
# hanges
# Turning stages
# Surely something light
# Layin' you had a distance
#
# Make he's round the way us gone and every darknwing
# I'm put you and you heard a word
# And dance as just a want to go
# I was your the heater of a hild
# aker
#
# Where it's the has to go and with you
# I've got a look
# Stamp it out in the heater
# You know when I'm like a night
# Can't you see
# You saved and she dress insent
# Say it's so long
#
# Oo
#
# ----- diversity: 1.0
# ----- Generating with seed: "hanges
# Turning stages
# Surely somethi"
# hanges
# Turning stages
# Surely something new the queenning for cover
# Feen sensing that you've stolg do straight
# Just didnen to the dark
# Hell up to you
# Where wery everything I want to be coming is a word
#
# I we need to go
# Now I love you hold out down on earth
# You're people while you and I was ins you at your forget baby
# People up and morning night, what you lough
#
# Baby when you put you will it all
#
# ill the scor
#
# ----- diversity: 1.2
# ----- Generating with seed: "hanges
# Turning stages
# Surely somethi"
# hanges
# Turning stages
# Surely something seel over me
# douse's what I set inside
# I I love of the with you runeess malls
#
# [Chorus]
#
# yous vills what I know
# You boy, bister to and you th the heart
# From drerive boby
# And this bad let will dear prove
# I who my miy
# And felstin' for it
# Armo you, heydone you the onevory on a ki
#
# C'art rewing the good tell me, becamoming the way voic in't time
#
# I mighan it ueder them sta
#
# --------------------------------------------------
# Iteration 54
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 0.7398
#
# ----- diversity: 0.2
# ----- Generating with seed: "'t let me carry on no more
#
# Stop me,"
# 't let me carry on no more
#
# Stop me, stop me if you think about
# I got your love and the way your life and no one night
#
# Let me do it
#
# I want to hear them call
# See come true free
#
# Hold you wing to you
# It's the only when you should be
#
# The man I long
# All time I'll be good to you
# I'm a wonderful time of the night
# If there's any way
# I want to los ok
# And the world no the start
# And the magic
# The stage on th
#
# ----- diversity: 0.5
# ----- Generating with seed: "'t let me carry on no more
#
# Stop me,"
# 't let me carry on no more
#
# Stop me, stop me if you think you've
# Heard this must be
# The more finder
#
# Set me free
#
# (chorus my fairy time
# They know it was you will be
# The magic
#
# The man I long
# Sweet romance
# Ah, ah
# From the skeencting to the way
#
# He was makes you feel good
#
# [Chorus]
# Well he take my fairy the man your baby
# Can't you think about
# I want to hear my heart
# And the world only king of
#
# ----- diversity: 1.0
# ----- Generating with seed: "'t let me carry on no more
#
# Stop me,"
# 't let me carry on no more
#
# Stop me, 'tous)
# Talky, hom all I creed
# A reucand the stage
# You'll me loke and you hide
# You play it's stats rais dreaming you
# Don't you the onl to go chan he thing for a loneceioncy
# And time to my heartcue, we just nevver knew a chos
# Like the again sice the wind
#
# Breath of he wep
# Besot faits for all time
# He's pushin' traven or
# There's a face true long the stands
# Got those can on m
#
# ----- diversity: 1.2
# ----- Generating with seed: "'t let me carry on no more
#
# Stop me,"
# 't let me carry on no more
#
# Stop me, ecevide love five my now
#
# hope there aglets my out of it's not now
# Always lues my stand
# Alreassed indiouse baby
# Tister when you've been goin' to the selfole
# I said on someone exis
# Come just stop me
# I want love another tear the rack I love bl right.
# He's must masther fall of m joye baby
# I love to love you no, it.s
# Talk the heriving to the night
# And baby, reechife
# I know i
#
# --------------------------------------------------
# Iteration 55
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 0.7390
#
# ----- diversity: 0.2
# ----- Generating with seed: " me, try me, try me, try me
# Anytime, o"
#  me, try me, try me, try me
# Anytime, oh tried my end
# The man I loHad you
# I want to get hurt and becaise
# The boy as closs
# The one who cant me
#
# Shablamida didn'
#
# I creet
# The one what I say
# I want to see your believe
#
# The one who carry on
#
# I want to see you can your mind
# The mosen that me so comping the best
# Summer fever
# Summer fever
# But I called me awake
# I this like to my miss give
#
# The one of a c
#
# ----- diversity: 0.5
# ----- Generating with seed: " me, try me, try me, try me
# Anytime, o"
#  me, try me, try me, try me
# Anytime, oh tried my heart
# And I see is the way to me
#
# Oh changes inside my heart
# There never essing, I'm aling the city
# Suzanna use and won't hat how
# I one better beware, better beware
# I don't want to get hurt and before
# We as what I need
#
# The would get a hoply
# Something hands in The better know
# Sweet as can
# There's a rumour
# Life is a happening
# I want to show you the way there
#
# ----- diversity: 1.0
# ----- Generating with seed: " me, try me, try me, try me
# Anytime, o"
#  me, try me, try me, try me
# Anytime, oh then just what I need
# I can't home to play
# A she'll you are
# Chirusure out of mind
# There's ancha]
# La, its road away with the rain
# Look you down the spund for a coal
# It's change on the dance
# Stop searchin'
# Things one of is vaiting
# Blbed all love bluck around
# The first menstill flow
# Domino, domino
# Want to flaunt it out fast
# Talking me now ungell it's
# (Tehone back in th
#
# ----- diversity: 1.2
# ----- Generating with seed: " me, try me, try me, try me
# Anytime, o"
#  me, try me, try me, try me
# Anytime, oh babbgescimpr of life
# You took wonderful time please of every mind
# (Sally god sare a dance in like comown
# On the raic catschulen't in your name
# But you are lovin's far him
# I just don't do
# You she romance
# Ting your alones
#
# Love to los to go
# Domin your lapby as what I won't you
# Summer feel
# But I called me to what wor days
# Love yo down anderf womanna
# Don't want to tell yo
#
# --------------------------------------------------
# Iteration 56
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 0.7394
#
# ----- diversity: 0.2
# ----- Generating with seed: "lusioned
# He just walked out of my worl"
# lusioned
# He just walked out of my world
#
# I don't want to get hurt
# I don't want to get hurt
# I don't want to get hurt
# I'm not the one of a little
#
# I don't want to get hurt
# I don't want to get hid just was a life
# You shouldn't want to go
# I leave you
# It's a breath of his fair fpace on the heale
# The scues are night
# Say it's wall her so sputely
# I'm a little misfit
#
# I believe is the last daby
# And it's the on
#
# ----- diversity: 0.5
# ----- Generating with seed: "lusioned
# He just walked out of my worl"
# lusioned
# He just walked out of my world
# You're gonna miss your love
# It's all has love, oh
#
# I was alow
# So much no man
# The scues are night
# Lucky on the heale
# The scur songing for the ground
# This stranger
# That you want me
# Best if you think you've chinl ened say
#
# I'm going to feel
#
# The scurting newn
# It's way how I need
#
# The hild her should people
# The man love is but you
# I will go away
# I don't unde
#
# ----- diversity: 1.0
# ----- Generating with seed: "lusioned
# He just walked out of my worl"
# lusioned
# He just walked out of my world
#
# To do
#
# Baby, seer any wome to the
# Warts somewold in a crazy spinit and really stage
# Might on the heale has too much
# Now I leave me
# (If need another heart things
# If you think about, are a you want to feel
#
# The oneping down the familive, I don't could a ting
# Is only opene nowlet him just wait you
# I won't wain''m you
# It's a breathing down
# Don't those away
# BuLy, don'
#
# ----- diversity: 1.2
# ----- Generating with seed: "lusioned
# He just walked out of my worl"
# lusioned
# He just walked out of my world
#
# Rested up mine
# To get to dream is what it it through my fapples
# In love will last fool you may
# (enother wantsly
# Rinbe in to my heart
# youSe!
# All this doesns pra's
#
# Starplet higher bright hat lover, letty to share
# Sading for con your baby
# Find you
# I'll things wouttide while with be
# But you're never had and song
# Briea loving gird, you byole out on eyes
# There is the
#
# --------------------------------------------------
# Iteration 57
# Epoch 1/1
# 78956/78956 [==============================] - 44s - loss: 0.7339
#
# ----- diversity: 0.2
# ----- Generating with seed: "nt him out, I want him out that door now"
# nt him out, I want him out that door now
# So much someone the start
# And it's a rabe it's the boy
# I want to see you can set me free
#
# It's gotta be glow see
# It's a what I'm looking and she's got at you
# I'm a wanderer
# Something nines to go, you and you are?
# Who do you think you are?)
#
# Sill be there free
#
# I want to see your love
# I got your love and baby
# I'm a long love
# I love you, and it's all time
# There's a
#
# ----- diversity: 0.5
# ----- Generating with seed: "nt him out, I want him out that door now"
# nt him out, I want him out that door now
# And when he sally get over me
# Listen to me
#
# Waitino for a racin'
# The sings that fast fairy tale high
# I want to love you wine hear out
# And that I can't get this one
# Stop me in your feet
# Sweet love
# I'm gonna make it really fill my said
# So be cra, domino
# That me so stronger stands
# Something up your love
# It's all that I can thing this maging for me
# I've got my flien's over m
#
# ----- diversity: 1.0
# ----- Generating with seed: "nt him out, I want him out that door now"
# nt him out, I want him out that door now
# Bod hugh all the lesse the seaders
# Oh baby from sheep your heart
# Shabt, domina, domind, you're still take a time
# I've been such yeah
# To be going love to the night.
#
# Like the purness by cour out of your baby
#
# Fook up routing for love
# There's not in tell me found high after got a liolut what you
# He's oking
# first at me full of my life
# But I was I can think about wort
# I've
#
# ----- diversity: 1.2
# ----- Generating with seed: "nt him out, I want him out that door now"
# nt him out, I want him out that door now you know misfit
# Cwirat that whore with surswer
# Bren sill day know, a day
# ...
# Bhoke connauss lady outer in a time of by body tald glad tus)..bahan ir the back to get
# But somy dausion that I'm vein's go
# around so be grtis claces
# (ah must going to carry on the hourt
# You tome without loving for you look for thoseness again
# Oh, I cannee's with him
# To da lett, stath around
# That yo
#
# --------------------------------------------------
# Iteration 58
# Epoch 1/1
# 78956/78956 [==============================] - 43s - loss: 0.7312
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# I'm free
# Now when clouds surround me"
#
# I'm free
# Now when clouds surround me
#
# I want to make you want me
#
# I want to set me free
#
# I want you just a breation
# Of reamic and belong
#
# I want to love you back
# And I can't you got a lot love
# I was make it is be
# Oh no, it's not to to strong
# I wanna world to be the heart
# I can't you see
#
# I want to love you baby
# I love you, a man always but it
# If you wanna heard the man a wold
# I don't want to get
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# I'm free
# Now when clouds surround me"
#
# I'm free
# Now when clouds surround me
#
# Shading on the trand
#
# Say something nice
# To find it over mever
# Summer fever
# Summer fever
# Summer, summer
# Love is a way he time
#
# I saw you wanna heart
#
# Love is any onna of your eyes
# And I want to love you baby
# I love you, a man always but all the time
# I don't want to get hurt
# I don't want to get hurt
# I don't want to get hurt
# I don't want to get hurt
# I don't want
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# I'm free
# Now when clouds surround me"
#
# I'm free
# Now when clouds surround me
# I got your love
# I always sound's burand
#
# peope ascopade diencto gave souler
# Do no dance withoul
# To and full the hurt
# I got your love and there and a crover
# But ion begind to playe the last droo behing
# Why the stater
# This bad breation
#
# Nobothin' to pull in him
# And I know those there again
# Oho, oh I wanna love
# Ooh so e've been so had the becaust
# I go way her it's ove
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# I'm free
# Now when clouds surround me"
#
# I'm free
# Now when clouds surround me
# Someone of sance
#
# dous up romance
# Where it's to pitt... our of reper
# chand
# Bring thereI' to are the way out you find 're me, and puryin't find
# now that you could be
# Dung no romance
# Oh protectilanderstect out there in the night
#
# Now, love had she .
# Stomme to me, trice love you
# What keeps and then't you knew you can be token.y ouf you to my misper now the keye
#
# Then in m
#
# --------------------------------------------------
# Iteration 59
# Epoch 1/1
# 78956/78956 [==============================] - 43s - loss: 0.7257
#
# ----- diversity: 0.2
# ----- Generating with seed: "ou're standing unaware
# I'm filled with"
# ou're standing unaware
# I'm filled with me
# And I want you to stay go
#
# Ooh baby, back in love
# I'm a wanderer
#
# I want to make you
# It's not the way that I need
# I want to me baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to lo
#
# ----- diversity: 0.5
# ----- Generating with seed: "ou're standing unaware
# I'm filled with"
# ou're standing unaware
# I'm filled with me
# All you the maso
# That's what she never we can the messad
# I was a mind
# We'll me, this samers in my heart
#
# I want to me baby out on the same
# Take a million your love
# This match you want me
# Love is what you as here
# From me all is all reachifnder the lady of the night
# You're gonna pain the reasion, oh yeah
#
# I love to love you now
# I want to mover me, toh a man she'll be
#
# ----- diversity: 1.0
# ----- Generating with seed: "ou're standing unaware
# I'm filled with"
# ou're standing unaware
# I'm filled with me
# By me's be traming
# Oh yeah....
#
# This me, don't be nother mecles, meced
# From what couldn't find me
# I love to know when I feel you
# Oh it' love will give you
# on me dance where water
# It's a had to fing the
#
# Hold me, oh begure at the wold man
# At true is hears of it thooufles
#
# Say sure runsing
# You're ly craming is wrong we'r
# It it comes with the won o worromen
# You'll be
#
# ----- diversity: 1.2
# ----- Generating with seed: "ou're standing unaware
# I'm filled with"
# ou're standing unaware
# I'm filled with but he's ten it
#
# Our love
# Like the only get what passs we could night of I know to go   never had a botting high
# With hambe sonm that't you
#
# Me feeling flaw hold
# And don't kep umben 'cause the joyeas again
# The onegen set it one heart of his sing
# We're all my dreas and out,
# Water for ery lofe mesued me
# Lothiny will be love you'll promided go
# i lone live and baby I fever you

# %%
# sentence 1

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = 'Loneliness is always looking for a frien'
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Loneliness is always looking for a frien"
# Loneliness is always looking for a friend
# The magic
# And you are the bet you want to be
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to lo
#
# ----- diversity: 0.5
# ----- Generating with seed: "Loneliness is always looking for a frien"
# Loneliness is always looking for a friend, you and me, we can
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# There no the day we was a please
# And I don't want to get hurt
# I'm not know it's all of life
# This is hard to be good you
# If you the time
# I don't want to get on a singt
#
# I want to me baby
# Hoars hard asofe
# I can't even the melody
#
# From you are my life
# It's what hoar believing I feel like
# This is the holds
# The only one deep your love
# This is my life
# In and hey don't be all the perfect lover
# The prayy's and last dress
# Musut hear this made the start
#
# One
# You may never which take a singget
# And I love you, love you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need
#
# ----- diversity: 1.0
# ----- Generating with seed: "Loneliness is always looking for a frien"
# Loneliness is always looking for a frience dies
# Fascination you agaple
# The day I'm aframing me
# You shouldn't while you and the first a chall on
#
# Then you know I want yat fave you are your life is know
# This is the love you've got and she darinvpt world
# Want to me baby was key
#
# Singy Chind a mind
#
# Bring the nead you want me was life
# You and I feel like
# The love that I can't live you
# A love ion ha's the hiss will be intold
# There's start)
# Bring the wals detion chuife away
# Well don't the mighty king that get
# We've got to treck go
# And need up to the tep
# I've love we said my milune
# Time you to the wild one night that reamo
# And go kinder aptered higher to go
# Love's unk you
# It's so got nugforgice for my fair
# And there was me, cry musy they won't ain no dadin'
# Ride over bn you
# Breakdown, over baby
# Sun sy prity cat get out to be cry and spirit of reach
# Ooh fectonh clack affair, sp
#
# ----- diversity: 1.2
# ----- Generating with seed: "Loneliness is always looking for a frien"
# Loneliness is always looking for a friend
# rectever
#
# I love to love you baby, baby and I was by
# Oh pectice
# 'Cause truady feel but frre friends, fait, worrdme to searom
# Brother want I from noth)
# laby, you cure inside
# I'll be syfild of just for ever be aft's righ from you
#
# I leave you and mose wrong all
# 'Cause wh, housee, oh, the lady of night
# Just days
# To ho on togayhant outer then tonight in the soul
# I can teach our end
#
# Stop me, stop me if robest waise
# Oh baby it's no true fver has it tooh
# That I soul
# (Igse you knew all of me
# Sweet, dyes who it's kawins right
#
# Try rusill you don't ksy
# Brenging I've done the doesnignwised glass
# My love seem left you
# There's so ware your all
# Ah, you like you breath you
# rim sair
# Was must hear it, whicked out of me
# It's stared and als around that you cay me ride
# Etous
# Cause I'm a wanderer
# We've beel aupelcle with you
# I'll prace the

# %%
# sentence 2

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "We go hard or we go home \nWe gon' do thi"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "We go hard or we go home
# We gon' do thi"
# We go hard or we go home
# We gon' do this world
# Then you're the one that I can the meling
# And the day we can be tonight
#
# Say so dark strove
#
# Try me, try me, try me, try me,
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try
#
# ----- diversity: 0.5
# ----- Generating with seed: "We go hard or we go home
# We gon' do thi"
# We go hard or we go home
# We gon' do this world
#
# Come on
# watching to the lasthing
# And the starround her essing
#
# So she well the baby I feel is
# So mucjey reasting that fister down
#
# I want to make hear you
# And it's only you are
# He'll could be to a word
#
# Ooh let me down
#
# Baby, she, I how more
#
# Spest me all up to you
# I want to let he fight at the light
# I can't even me, this one
# That I'm hung wat he's a gind
# And when you seem to stay with a litting
#
# I was man he way
#
# I've been oh christmas is himing so break a mill out out
# This state of into smeall
# I want to me a roaing you
#
# I want to feel love
# He's ok you and mever after we new you
# I want to me really know
# That's what I say.
#
# You're gonna make you and me
# The one they was a stare
# You came out be so darens
# And the world we couldnct from the bad that you
#
# I love to love you baby
# I love you and a daddim it
#
# ----- diversity: 1.0
# ----- Generating with seed: "We go hard or we go home
# We gon' do thi"
# We go hard or we go home
# We gon' do this over you and me, you loved out to you
# Can ever love you down toing
# You've got me wish me
# un hurtorick to nacee your holds
# Tell it's body on the morning, even ain't going to the aches
# It'll all the weele you
# And you think about ruisal song
# I want to me or real the feet
# the door man
# They're love will be from you
# Oh fer ared you will need hurt with
# You've true sill
# And youlfever all part of mince
# And but themes they cameber foicent
# Hhoring strong better into love
# Oh spring affair
# And the morace of love for break
# In Rongy and I can
# There's so wanta shouins in the moseces
#
# Try to me) how don't you think you are?
# Who do you think you rejeumas making side
# Thinked of a millioning me
# Oh, I want you know
# When I'm gonna gonna make you and you'll
# You havel he's kies start, oh, hold on eyes
# That's about twaice will be gottenimes
# When we feel is
#
# ----- diversity: 1.2
# ----- Generating with seed: "We go hard or we go home
# We gon' do thi"
# We go hard or we go home
# We gon' do this chycause goodss
# [hover in love
# Ant's the ternal our Love, mecawe
# I want move to me
# Whoa ouse he faels singide aself as veice gonna on get
# My lightings
#
# Swever looking
# I'm gone me
# (now a mighty from changecaused
# Youg starry of dres, disten se
# Never had me
# Drews it was straps, he's may to be the wiys
# I need soor world time
#
# Hold the faryh behind
# We're back your oway
#
# rabrersjughts chance the vin'rn knows
# Yeah out I want him
#
# Mabrepaling are in the gair soulen mesions over
#
# Harmony, gitsjulh stay how to find
# The music angs dayt of chay away
# Ness to head me to repuck nownriss
# If you wanna get of life in beant
#
# I feel how missed
#
# I always sn made
# I want yod we had only
# A supernnt flows ware bore 't have time may me cry
#
# Yes my waiting for cover
# gore mucoury undion in shigh
# They fined you
# Just from you're alivu, love t

# %%
# sentence 3

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "At first I was afriad, I was petrified \n"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "At first I was afriad, I was petrified
# "
# At first I was afriad, I was petrified
#
# I want to me alone
# Then you're the one that I can the make
#
# I want to me baby way
# I was all of live
# The one that I can the melen
# Love is be
# You know my my mind
# And I'm looking up
# I was alone feeling me
# And I'm looking up
# I was alone feeling me
# And I'm looking up
# And I was man the start
# To find it's no more
# I was dreir with the stare
# And I'm looking up
# I was darking for cover
#
# Try me, try me, try me, try me, tr
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# y me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, tr
#
# ----- diversity: 0.5
# ----- Generating with seed: "At first I was afriad, I was petrified
# "
# At first I was afriad, I was petrified
#
# I want to me baby
# I love to love you baby
# I love to love you baby
# I love you baby
# I want to do
#
# I creet the winded loves and the dance
#
# She was for the darknwing
# And I want you to find mever anything
# I'm all she did it's all had the way
# And if reclich will get you
# It's a wonderful, wonderful, wonderful, wome here one don't be
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love you want me
# I want to me alone
# Only the mesise for cover
# Running for cover
# Running for cover
#
# Try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try tears to at the mission, I
#
# ----- diversity: 1.0
# ----- Generating with seed: "At first I was afriad, I was petrified
# "
# At first I was afriad, I was petrified
#
# So her having love's all the door
# And through mister, much with you
# I was yourself in me
# But left the most of a crazy gnore
#
# Ride over backwhill came after hurten your 'mages
# Said iat for me fell is wrong
# Where it's no nother me, baby, back inside obother mine
#
# less the chose so long love
# And the holds of love
# Take the when better tear that I'm strong stand
# And but I've lead you fell you
# Ill we'll been sun is his stames
#
# Once while just a bire
# You've try me, try me, strosjugh of the night
# Theaking move walks
# The pernce of love
# Oh you're mine, baby, we'll in the eaden
#
# Got together fait, wome with a memory of away
# It rencipe your feet
# He'll was a wold me
# Thereving for all times yourseence opent
# 'Cause I'm go
#
# icapy a stars
# Love is be
# aside for eyid mill known side
# And out to fitlyounger me, oh at night
#
# I want I wanna head y
#
# ----- diversity: 1.2
# ----- Generating with seed: "At first I was afriad, I was petrified
# "
# At first I was afriad, I was petrified
#
# Wroar inght for godss
# lack music
# And she's got embengine, so be with ked in your fever, but breakeonxwicoughting
# Seling in your gurtarle, showing fet reastery rading fet
# We loved me to remicare(mary spuke rnow
# Mabirathing one partsion walk unrey , I amone me
# Baby yef amasida dresse
# For are along
# I was
# Face muches people
#
# It makes me can in me
# I wanna down to life
# This less me
# Love's angure childreh before go
# Got nw too man stand, don't want up peacep
# Well everysther, hes sure all thesn cry togething for love
# And she was roses's rore for that door
# This peess, no, it's not to you
# You may that love you belong
#
# For when yeah, we could make you and I find you
# Whe read you that you're me
# 'very lous nights amonie at all
# A vereed will always be
# Think you say I know they at a word
# I don't ware to !
# Bbowhe, oneed you pul oh you try tears)
# Of

# %%
# sentence 4

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "Young Money, Nicki Minaj, Justin  \n  \nSh"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Young Money, Nicki Minaj, Justin
#
# Sh"
# Young Money, Nicki Minaj, Justin
#
# She was my life is always be
# You're gonna make you and you are
#
# I want to make you
# It's so good you
# I was feeling meching
# I was man the start
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love
#
# ----- diversity: 0.5
# ----- Generating with seed: "Young Money, Nicki Minaj, Justin
#
# Sh"
# Young Money, Nicki Minaj, Justin
#
# She was a milay what it is
# That they can't find to you
# Well me, I want to dance on the wind
# For the start with you
# I'll give you and I
#
# One night if where you lead you
# I'll be the tree and gonna go
#
# I want to make you
# To find the matck of secled spirit for the don't be tonight
# I was all of life
# And he is belong me know
# Love is what he's got a look on hel
# Love is be
# way her in the stare
# And how the same I'm stay
#
# I want to me reaching
# I was dreams are all the time
#
# But he the day where you lead you
# Baby, you'll may home at up to the night
# She said is the day
# He's nothing for all the last dance
# The even but I was all go
#
# Oh chance the man I love you
# I love to love you baby
# I love to love you baby
# I love you baby
# I love to love you baby
# I love you, and bring that her days
#
# Sun even you're all is all if you think about
# I was
#
# ----- diversity: 1.0
# ----- Generating with seed: "Young Money, Nicki Minaj, Justin
#
# Sh"
# Young Money, Nicki Minaj, Justin
#
# Shoulden.
#
# I'm a wing so worry
# It's hard this left me,
# Striped up the door't my life
# 'Cause I'm got the wall on
# Forever are night for behincine, suween's old has my heart
# Con'm heard the time
# Take your costite own
# I see my hope of )  away the wind
# one day
# Sweet
# They beears It's very
#
# We'll keed you wined so mine
# And he's purking and she's girls
# Let me know it's all yace  gunna compleneer
# But string down shoulden
# They don't wan't seem to stay in like
# You're walk you arem love
# I've gotoughing that you together and messer
# Lose with yeah
# I really do
#
# Sud man day
#
# Whisark to my heart and bever
#
# I want andeling flown
# Stop me something stand
# To you are your cover where you live to tro mine
# I'm one man's with me
# You mpece the more filling
# And the moment's over back
#
# So the man ars, you're m
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# ide
# The only wanna want to be tonight
#
# ----- diversity: 1.2
# ----- Generating with seed: "Young Money, Nicki Minaj, Justin
#
# Sh"
# Young Money, Nicki Minaj, Justin
#
# She's the believe undion be ghad
# When yescee this live
# ghong
# Move players in the night and she left in in recled
# There's are re, stagr how I'm mn by divit
#
# Con', cleep thep the what you want love king of mesisill
# For theper you living down vime you does like yov
# You, leve me how more
# I promise to toejoked you're belie life where you
# We're gonna miss just once of almoyed time
# Let me epting strong to )
# Flaces, messand)
# I was feelingopinsises up love
# Of a words love , just be say love a distt in your arms even me
# It's only you-maside of my haar
#
# Starply as chy
#
# Oh tell me what firstlizan
# Blong up much I ant you
# Everyce're home it real thing
# There oth rool who cour yearstil
# I'm the king will love kingion you
# Take will me, baby, baby, and fulling me
# un my mind
# No one what I'pll let like out yean
# get your chast she'll be in your love
# How to l

# %%
# sentence 5

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "Life is to be lived on the positive tip "
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Life is to be lived on the positive tip "
# Life is to be lived on the positive tip down
#
# I want to me baby
# And I want him out to be
#
# One night if when you
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love you
# I want to dance to the wistYen me walling
#
# I want to make you
# I want to make you
# I want to me baby
# I want to make you
# I want to me baby was a mind
# The magic
# And you are the time
# I want to me alone
# They was a million night
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
#
# I want to feel like the masion, you're had one night
# When you lose me
# I want to me really know
# That's what I don't want to get hurt
# I want to me want for me
# And don't you know that I can the messadion
# And he was around the start
# To find it's own
# I won't tell my soul
#
# The left me what he's not the way you
# A love you seem to the
#
# ----- diversity: 0.5
# ----- Generating with seed: "Life is to be lived on the positive tip "
# Life is to be lived on the positive tip learts
# Sometimes to find it's over me, tommame
#
# Hey dister and cloud
# I know they stare the singt how to listen to you
# I'll be going that I can he tere
# You're my how the world
# I want to me a reasory
# We're all you to flaunt you
# I was feeling mecto
# What you feel love
# I want to me a reasory
# You're never left me what he's not she
# And I want to my mind
# I want to see my hand I can
# The mighty king the world
# I want to me alone
# That makes my mectem
# Try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try me, try m
#
# ----- diversity: 1.0
# ----- Generating with seed: "Life is to be lived on the positive tip "
# Life is to be lived on the positive tip lesting
# one now the world will I stand hil whwpard
# Darkno on the trace like to me
# It's daithic baby, it's noneed yours of falt a bores
# In here to my heart it is no ent
#
# Carryn't try tear whished too
#
# Warer hopever me
# Thous themes a helf insevill come this grace
#
# Yes be seem to be what she'll be
# All the live go, on, my mind
# Whrapbe made the bad  want you
# I will last what I don't have think you
# And sencing to me, carry in yoursed
# Stmight doess
# etter whish had time
#
# It's what I do
#
# Heaven thro's so long resing
# To hid her fille mechicky no one
#
# Frim me ain't which
# And we've got to un the magio
#
# You're nice knows my soul
# You those to fine to re, I would side
# 'Cause that I can't go on no more no
# Eniught me away
# But the windows the out when you want me
# And he came asold wnong feeling ins for me
# And I know, it's not the way
# Still
#
# ----- diversity: 1.2
# ----- Generating with seed: "Life is to be lived on the positive tip "
# Life is to be lived on the positive tip your love
# This is you again
# the cramicon'aded will come her
# Take never know you and dane, what's
#
# Love's in the eye on east life
# one wanta feel yourself in a liout a craby
# She's the army of she giving aboves
# Dun't going tool herce him a live, ,tame, mister this might when I
# My mirad
# Body, there's insiog's nobody, fill me to a lo live is doinly
# Anking welcout me no much
# On you the sun go oo streck but what we time
# I said made milands me
# From the skyeuming heaws
# She mouns baby
# Tild my mind I want to feel
#
# But if you're me, will never feel is burtueer your agmilesed
# And just hpat your wanta eyes him at h
# I always be anyone heart
# And 'cause they knect, those hard for my essence of contr it
# We all love grack,upbention of my heart
# It's rotet more the woater
# Take a Let me you
# I, I ben me be like a when I
# Oh sjusis go to a be
# My friend that face I

# %%
# sentence 6

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "Another night I'm waiting for you  \nWait"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Another night I'm waiting for you
# Wait"
# Another night I'm waiting for you
# Waiting for a time
# They was a mind
# The magic
# And you are the time
# The one that I can the melody
# When you're gonna make you
# I'll be so long to feeling go
#
# I want to me baby
# And I want to stay it all up to you
# If you want me
# If there's any wom down the start
#
# I want to me baby was a milands
# The magic
# And you are the time
# I want to lost to stay in the wind
#
# So me we'll be the hope and so in the star
#
# We'll me belone
# The one that I can what he's got a little
# Trip to nowhere, trip to nowhere, trip to nowhere, trip to nowhere, trip to nowhere, trip to nowhere
# What you the most be
# And I want to make you
# I'll be so long to feel yourself
#
# I want to me baby
# I want to make you
# It's all I ever think about
# I got your love
# I want to feel love
# I want to lost to stay hid
# And I'm looking up
# I want to make you and you
# I was darking for cove
#
# ----- diversity: 0.5
# ----- Generating with seed: "Another night I'm waiting for you
# Wait"
# Another night I'm waiting for you
# Waiting for a coary and we call
#
# I want to make hear deep your love
#
# Love is be all the compaic
# And you think you are
# I love to love you baby
# I love to love you
# I can't does my mind
# A lookbepay mission, you should be from
#
# The mad a sill me
# It's a wrong it
# They didn't was a spead
# I was I don't wanna work that had you
# I want to dance to the end
# Well the light my life is hore
# And I want you want me
# And I'm looking up
# I want to triss to the winds out, stronged
# T
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# his is they don't believe, it's not the way
# Oh no, it's not the way
# Oh no, it's not the way
#
# But you say you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do
# I don't want to get hurt
# I've got me feel
# Sometimes I feel like the moon a world
#
# Oh no, it's all had
# I want to be tone me
# And it's on
#
# ----- diversity: 1.0
# ----- Generating with seed: "Another night I'm waiting for you
# Wait"
# Another night I'm waiting for you
# Waiting and creaving in him
# Dance wherever you are
# Now it's not back to giving in the porching
# Un your with to turn the ust
# To be going that find of win me
# It's the way your of love i'S oh
#
# Want to go, all that I need you
# Love me a neeping we need if you why, to feel and dande if whith
# To feel the bening clounde , just cry lover, so lastmeer
# He's a reca-used on, hold no time
# I have you asin' that how to forgive
#
# We'll maggin..
#
# Tonight I want you
# And I want you to stroul my him
# And breashing voicing the
# And I'll be free that I see
# And morever and would find you
# We can make it, we love a wos from don't you running
#
# Hon's Romeo
# TV
# bister wants fleem to the waiting
# Don't know it's not me now inshe me to be
# Heardrefarting light
# He'lls true in bright
# And bect) fry me, stop me if the winds
# Tell I falkisuscome you
# And she's got it, true is
#
# ----- diversity: 1.2
# ----- Generating with seed: "Another night I'm waiting for you
# Wait"
# Another night I'm waiting for you
# Waiting for me
# Sometimes that firoling down the stoness
# u you'll just aull was are you
# Oh yee's
# On the radie
# You up the pervest are fined and clame a music
# Over dance in the mind
#
# C'Thing to too my eno love you, live to peeling in me
# I would site hughing by
# And complete to go, so much me
# And that's only out, standers breatce for behind
#
# All the melace love sould it's no intre
# Let's me feel Oh what's sister
# How it's so it's for side
#
# She's nuguur agoway)
# It's all so run what you need your sood
# Oh yes came
# You rumer, whoadde arebedaring by the as's wring
# Holding for colre
# Thouish
# This babyb]
# A super to that dream
# a searing down breath
# So yon
#
# Let thoice we left to find
#
# [Dzeyonply guare
# And I'll
# nother theme a disting and a'red around
# Wisters(in'cake your sweetest lete to the player
# This is so gram long ever
# Love is sing for ator

# %%
# sentence 7

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = 'Back track, listen, stop that  \nBefore e'
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Back track, listen, stop that
# Before e"
# Back track, listen, stop that
# Before everything I feel is
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love you
# I love to love you baby
# I love to lo
#
# ----- diversity: 0.5
# ----- Generating with seed: "Back track, listen, stop that
# Before e"
# Back track, listen, stop that
# Before eyes beftakes to forget
# The roading everybon you down the warroult away
# We we're ly come all
#
# Where you are your love
# The one fairy talk
# To turn they can be sold
#
# On the radio
# Got together the world
# This is my baby
# I love you, and recliche
#
# I want to be nother me, tommame to stay
# To find the sadns in the stare
# And you are the songing so god
# The cold me, call, you got me
#
# I was man the day
# Time, time of the stare
# And hopes without to find
#
# The live the magic and dance and she dive you and you are
# I would never could she me clee
# And I'm looking up
# I keep it, they strep your mind
# And you are the time
# To turn the way you and me
# There's a rumour, tu faster where you lead you
# And that's out me
# Love is go no toruced
#
# Oh no, oh no
# Come on dream of ehing lought
# Ooh
#
# I want to me reaching to congy
#
# I love to love you baby
#
# ----- diversity: 1.0
# ----- Generating with seed: "Back track, listen, stop that
# Before e"
# Back track, listen, stop that
# Before eyeply dance this where you in his see you
# They was a miling clear at the bendThing
# Melody ion me
# Breathiouse child part of my heart
# I was kes always he love you
# Baby, baby baby, sweet him so cont to what's walk it carry on the corching ess
# You've won me, heyd you s
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# eem to set it on
#
# I lesse to me wrong we not we nauten
#
# Say you know, I want yo
# We'll waiten your love you've left had the time
# No me we leod
# I am out bad
# This mas-iside of the world
#
# Brenather that making my ever's
#
# And all athebagens out to be scree
# Bring down the star tonim soul
# And I thought the way come
# That you are no love
#
# So darknwaver me beart
# (Chayss straid just a way your heart
# Aounds in time
#
# No do you want me
# And she'll ever the time
# You're walk godos chy
#
# Weake a somemer nevitain' toous time
# Try me, try me, try me, try me, try me intile himbe
#
# One
#
# ----- diversity: 1.2
# ----- Generating with seed: "Back track, listen, stop that
# Before e"
# Back track, listen, stop that
# Before eyes filling to my lifes bore
# And I went to all is hold it
# If dimissed
# They callen the laod the night
# I love you back to fight it, oh
#
# Now l when all strong another
# now you to me where you ain't going
# Hold you, l need to live I feel
# I don't have not better be
# To get up to and baby
# I got your love, ouce wathing fast
# Alp i would mesing in the eye
# And you the perking love
# The viss me(us ust my life
# Looking for coh te'll ecape your, oh, hownt icanty
# Chorus yest and cupch ot
# Enough that's nother and with you want to living know...b close.
#
# Her dister heartaght, I benws
# What you know my brace
# Love i'm light sforside you rejoice romanw
#
# Just like his me wale him,
# Fate my life
# If you the promimes to you
# It must chokes my hearthope the changege of god
#   chorusSmy sived to one with us almor
# She'll be all whisake my schet
# I've got my fear for

# %%
# sentence 8

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = 'How can a non-musician discuss the futur'
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "How can a non-musician discuss the futur"
# How can a non-musician discuss the future
# And I want you to stay
# To find the make you feel go one day
#
# The lights into love you, love you, love you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l need you, l n
#
# ----- diversity: 0.5
# ----- Generating with seed: "How can a non-musician discuss the futur"
# How can a non-musician discuss the future
# You're my a man like and no one now
# Oh I love you
# You may now the truth is hard
# I want to lost to the masion, you're me,
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# baby
# I love to love you baby
# I love you back will always be
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby, oh baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I want to get out,
# That they came all
#
# Shading for my life
# I wish you are
# To me belong
#
# Straing down deep it
# There is bestros stand
# Thereving I want to go
# I love to love you baby
# I love to love you baby
# I love to love you baby
# And I love to fat I want to it what you love
# I want to feel love
# Oh nohnging the lady of the night
# And you think you are
# There as youreakes me
#
# ----- diversity: 1.0
# ----- Generating with seed: "How can a non-musician discuss the futur"
# How can a non-musician discuss the future
#
# Hold the eye face that I mave you
# I would onever tear the world
# Take to gued it all morly, what you love you like side
#
# Fook your loneaw rire
# You've been of romance
# Lonen
# a mo's wrong every day a long
# Ooh baby playen secaus ase you are mine
# Disting as here one belong
# On Au
# "h ustckect for sleam
# Hey music just a hide theme
# And I'm reaching to forder
# I'll be going to you
# Maby was a melody
# And that's nothing fath for survives
# Breakdown, over sheep you know the wondely
# You've the time man doen the tems gram
# I'm fillen yourself break around her be
# Filling up to and cairading
# and wonderful, wonderful, itu"Yu's
# Sweet don't you one you set is to be light it's not the way
# Oh no, it's not the way
# Hold you want me
# I want to dance and reach wist a last darling down
# The love will last foreve
# 'Cause I'm a wandereror toh more than so powe berig
#
# ----- diversity: 1.2
# ----- Generating with seed: "How can a non-musician discuss the futur"
# How can a non-musician discuss the future
# And all has our courmLowe and but you
# Then it masit just chings to me
# You ak what you fever nuaving
# Whenever meance say, i home
# And only out, streperfulion yetems
# From the swament to t that's han
#
# [Chorus]
# A reattion, no he'll one
# You say dance apaing sawhing me
# And I'll pray before just I nongwalkin away
#
# Bi
# shouy so the lapblase the shad
# I baby, sallong voice go
# Then you are my em to the percee
# ust doen that down the start
#
# You've never loner time
#
# Linge in the wry
# And walk when you and on the world asting
# We've feel may loves me
# Loves for mecawe,
# Oh, I says a time
# I can't love you no, whulured state your a screwar your love
# And mectem one brow enough
# And ared up to tain my first
# Tell I'd is baby
#
# I was alive, it's all I ever think about
# We've got somethings time I'm in lungs
# Has you, oh then bluye
# Heard supenat efochi

# %%
# sentence 9

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = 'Hi out there. This is Shaun Goldberg and'
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Hi out there. This is Shaun Goldberg and"
# Hi out there. This is Shaun Goldberg and bectuning so go
#
# I want to me baby
# I want to make you and you
# And I'll be going to you
# I was all I ever think about
# I got your love
# I want to me by in a chought
# I was man the door worr
#
# I want to me baby out on the hold
# The one what you've had ending
#
# I want to make you
# I was man the wind a redo
#
# She was a man like and no one day
# And you are the time
# They don't want to get one
# Then you are the time
# The one that I can the melen
# Love is be
# Alm she's got a lood
#
# I want to me baby
# I want to make you
# It's all I ever think about
# It me the melody again
# Ooh baby, in a crazy spin, latt of my heart
#
# I want to make you and you are
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
#
# ----- diversity: 0.5
# ----- Generating with seed: "Hi out there. This is Shaun Goldberg and"
# Hi out there. This is Shaun Goldberg and baby
# When I know they do
#
# Ono
#
# I want to me real tiled
# Love is go
#
# The time of my life is what you leave you
# And I'll go
#
# So me we was me
# And I'll be good to you
# Oh as love a man aroll
# We've got to me baby
# I couldn't turn my life is all you
# The made to forget if you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you think you are?
# Who do you remoned any that how I need you, oh baby
# The sad so but hear my heart
# But string that fast fall it up your life
# This is my life
# And you the believe in you
# And I leave me all a do with you
# I'll go on a mind lover mecto the yeah
#
# It's a so stay and last what I say.
#
# So me birorning love
# It's only you, come to me
# There's on the other now
#
# Love is be
# All sy nitil love will last foreve
#
# We'll stand me wa
#
# ----- diversity: 1.0
# ----- Generating with seed: "Hi out there. This is Shaun Goldberg and"
# Hi out there. This is Shaun Goldberg and I whope had a hold
# Whb
# cean what man
# Turn the same is a band
#
# She thing's come, chance to be sure you can tearing
# It makes my I can the man
# And I'm rising, to king the more first
# Soncig'vill don't fare in me
# Iughing wers of the temess beftave
# Protection, time I'm a wander
#
# Or just the wild love will be
# You're my heart that I'm huster stand
# You seems we really whore you want
#
# Stop me, stop me if
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
#  remad
# he make ys I'm mecen the man she's )
# ois true love to my heart
# Tell me battime....
#
# Talking up   nugur know it's so go
# Where arefulin on the night at me
# I think you are your bwaic voic
# How you went you
# And the even but you and me
# But I couldn't want you don't believe, I want love you, oh, oh
#
# Showing me while
# In my life is honie
#
# You say when you can world
# Brack that world mall end
# But come hearts from one who would strefad
#
# I
#
# ----- diversity: 1.2
# ----- Generating with seed: "Hi out there. This is Shaun Goldberg and"
# Hi out there. This is Shaun Goldberg and I "a
# rmistance fair wall ever will be
# Forefolt me"!
# Then her lipse chance
# And we why me time we carry
#
# Custure, forgut the whe, couse
# And he's if all is just don't tell you shore away
# I want to go, so mall her to ever I plad
# I was yourself
# I feel us stay
# I got wimef the time
#  now that I I feel houren
# Blighter me's my a please
# Thin'ved all that I versel
# I want to makes me hease and re, no if you wan to nipp coaro stand
# Thereving staged you need your gair
#
# She was all shy hove
# Mifeting along
#
# bea's real maty fall, in him
# Breath is fast airht of a lineee
# Am, heaven be toougnick my time
#
# Heybefogning'coures harding us will boy love
# They're a can seadt came and since to a good you
# un just long up
# Love is where it seem
# And !
# Hold me's
# Like a danceup bight I've been ware
# Hoa drep you would just anything left found sadning
# Seems (ra

# %%
# sentence 10

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('----- diversity:', diversity)

    generated = ''
    #sentence = text[start_index: start_index + maxlen]
    sentence = "Whose eyes in my behind  \nI don't recogn"
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(900):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "Whose eyes in my behind
# I don't recogn"
# Whose eyes in my behind
# I don't recogned to say
#
# They was a man around the world
# There's a rumour, there's around to feel your life
# This is my life
# It's the only dimes
# And you are the time
# I want to love you
# It's all I ever think about
# I got your love
# I want to me not me
# And I want to make you and you are
#
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love to love you baby
# I love
#
# ----- diversity: 0.5
# ----- Generating with seed: "Whose eyes in my behind
# I don't recogn"
# Whose eyes in my behind
# I don't recogned to read
# Body too me is now
#
# Last don't betwer
# There's no more tears my life
# This is my hope
# It's so good at all
# I want to me alone
# The one day
#
# I'm baby will always be
# I will go with you
# I'll be schord
# You're never left me what him so strong
# Well be of my heart
# And she's got a look and make
# They was a new what you want me
# And all I can the met at me
# And he's not mecause
#
# Brong to my heart
# To find the mesise
# I want to don't love you
# I love to love you baby
# I love to love you baby
# I love to paught me to forget
# The roading everything
# Con't you the most a bround
#
# Hood to get them one that fill me
# All the lasthing for love
# The one are all the cot your with you
# Can't get to slace
# Oh, oh, oh I want you
# So me free that I need
# Hold you wanna hear think a didn't won't you
# You asf you are the only day
# one night at me wrong
#
# ----- diversity: 1.0
# ----- Generating with seed: "Whose eyes in my behind
# I don't recogn"
# Whose eyes in my behind
# I don't recogned know I got
# You took whworgd he love is what you ain't
# My life
# Why hear that's in the daddre
#
# Enough is enough, to prayer in which
# My baby love you, oh, oh
# Billy it's fant if you're made you ever the girl
# As put the time you ma-han
#
# And for love you seem amound
# Rounce on the soul
# No looking fords appenge
# Hry, my mind
# Baby, feel love
# I'valver fever
# Let memonise close me
# And are'res of redion stice ffflters inside
# No do nicamer in life wis anyone here incess and win to tors
# Stripber us but his reasire
# (Talk):
# The time the dey him to bake
#
# Love is be true
# And it's only you
# Canter of life
# To be tonight mince
# Stop me it's so lonely me, call, it chal
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# l go
#
# Coorus turnes yest loving in the rain
# A super through the weection
# To find me
# On a journey
# Breathonic when you're always don't be the vest last dress
# The listen
# Hown to f
#
# ----- diversity: 1.2
# ----- Generating with seed: "Whose eyes in my behind
# I don't recogn"
# Whose eyes in my behind
# I don't recogned me
# (see d, can giving's nother
# From the time, sand itn heart of his his mored
# That's know bring ho)
# Like to put he'll feel hide
# Oh as oh dream
# Porking oflfa]
# And make it his see is the wind
#
# One time for his all ..coou's with you
# He'll was a man she wisld the powes
# And parting to yougac, I'v to you
# nothing on usiod
# Hold help me dalk
# Ooh sad, you go
# The last sillinat but I'm oneed yourself in life
# We've don'a ty to you
#
# How I love to let it those what he's not that
#
# We'll une but I can't he're don't feel me left be of your love
# You shouldne who they playe girl shame at the get to you
# Seems the puctiont
# Turn go romance aporing alone
# Yes triss day hard me nawrection
# Tho's go awn camepand
# lus kept upon a staken
# And who's the bet you get it op me to be
# Love of here
# And it's wrong to be glad ont by be in you
# Chanis strong back to l

# %%
# number of songs for each artist
lyrics_data.artist.value_counts()
# Out:
# Donna Summer                                    191
# Gordon Lightfoot                                189
# George Strait                                   188
# Bob Dylan                                       188
# Loretta Lynn                                    187
# Cher                                            187
# Alabama                                         187
# Reba Mcentire                                   187
# Chaka Khan                                      186
# Dean Martin                                     186
# Hank Williams Jr.                               185
# Neil Young                                      185
# Indigo Girls                                    184
# Nazareth                                        184
# America                                         184
# Cliff Richard                                   184
# Johnny Cash                                     183
# Kiss                                            183
# Chris Rea                                       182
# Bon Jovi                                        181
# Fleetwood Mac                                   180
# Dolly Parton                                    180
# Deep Purple                                     179
# Rolling Stones                                  179
# Roy Orbison                                     178
# Rod Stewart                                     178
# The Beatles                                     178
# Morrissey                                       177
# Iggy Pop                                        177
# James Taylor                                    177
#                                                ...
# Side A                                           11
# Independence Day                                 11
# Walk The Moon                                    11
# Yukmouth                                         11
# Yonder Mountain String Band                      10
# Koes Plus                                        10
# Quarashi                                         10
# Yung Joc                                          9
# Next To Normal                                    9
# Xentrix                                           9
# Yeng Constantino                                  8
# Qntal                                             8
# Joseph And The Amazing Technicolor Dreamcoat      8
# X-Raided                                          7
# Young Dro                                         7
# Gipsy Kings                                       5
# Van Der Graaf Generator                           5
# Unknown                                           4
# Exo                                               3
# Soundtracks                                       3
# Xavier Naidoo                                     3
# Eppu Normaali                                     3
# Various Artists                                   3
# Ungu                                              2
# Zazie                                             2
# Exo-K                                             2
# Zed                                               1
# Zoe                                               1
# U-Kiss                                            1
# X-Treme                                           1
# Name: artist, Length: 643, dtype: int64

# %%
# Donna Summer song lyrics

lyrics_data_donna = lyrics_data[lyrics_data.artist == 'Donna Summer']['text']

lyrics_concat_donna = u''
for i in lyrics_data_donna.index:
    lyrics_concat_donna += lyrics_data_donna[i]
    
print(len(lyrics_concat_donna))
# Out:
# 236908

# %%
# Gordon Lightfoot song lyrics
lyrics_data_gordon = lyrics_data[lyrics_data.artist == 'Gordon Lightfoot']['text']

lyrics_concat_gordon = u''
for i in lyrics_data_gordon.index:
    lyrics_concat_gordon += lyrics_data_gordon[i]
    
print(len(lyrics_concat_gordon))
# Out:
# 230377
